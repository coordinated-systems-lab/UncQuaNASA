# %%
import sys
print(sys.executable)

import torch
import math
import gpytorch
import numpy as np
from matplotlib import pyplot as plt

from matplotlib import style
style.use('seaborn-white')
#torch.cuda.empty_cache()

#gpytorch.settings.max_cg_iterations(2000)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /work/flemingc/belal/anaconda3/envs/pytorch/bin/python3
# /mnt/bgfs/belal/4199077/ipykernel_102490/107199833.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn-white')

# %%
def cartPoleDyn(theta, theta_d, x, x_d, m1, m2, length, k_inertia, mu_c, mu_p, gravity, force, dt):
    theta_dd = ((m1+m2)*gravity*np.sin(theta)-np.cos(theta)*(force+m2*length*(theta_d**2)*np.sin(theta)-mu_c*x_d)-((m1+m2)*mu_p*theta_d)/(m2*length)) / ((m1+m2)*(k_inertia+1)*length - m2*length*(np.cos(theta))**2)
    x_dd = (force-m2*length*(theta_dd*np.cos(theta)-(theta_d**2)*np.sin(theta))-mu_c*x_d) / (m1+m2)
    # Euler Integrator 
    x_d = x_d + x_dd*dt
    x = x + x_d*dt
    theta_d = theta_d + theta_dd*dt
    theta = theta + theta_d*dt
    return theta_dd, theta_d, theta, x_dd, x_d,  x

# %%
# Uncertainty Sources 
m1 = 1 
m2 = 0.1
length = 0.5
k_inertia = 1/3
mu_c = 0.0005
mu_p = 0.000002
gravity = 9.8 
dt = 0.01

# Initialization 
theta = 0.3 # np.random.uniform(low=-0.05, high=0.05)
theta_d = 1 # np.random.uniform(low=-0.05, high=0.05)
x = 0 # np.random.uniform(low=-0.05, high=0.05)
x_d = 0 # np.random.uniform(low=-0.05, high=0.05)

# lists for storing results 
theta_dd_sim = []
theta_d_sim = [theta_d]
theta_sim = [theta]
x_dd_sim = []
x_d_sim = [x_d]
x_sim = [x]

noOfSteps = 12000
ts = np.linspace(0, noOfSteps/(1/dt), num=noOfSteps, endpoint=False)

for i in range(noOfSteps):
    force = -0.2+0.5*np.sin(6*ts[i])
    #force = -1+np.sin(ts[i])+3*np.sin(2*ts[i])
    #force = -0.5+0.2*np.sin(ts[i])+0.3*np.sin(2*ts[i])
    theta_dd, theta_d, theta, x_dd, x_d, x = cartPoleDyn(theta, theta_d, x, x_d, m1, m2, length, k_inertia, mu_c, mu_p, gravity, force, dt)
    theta_dd_sim.append(theta_dd)
    theta_d_sim.append(theta_d)
    theta_sim.append(theta)
    x_dd_sim.append(x_dd)
    x_d_sim.append(x_d)
    x_sim.append(x)

# %%
# Converting to Numpy Arrays for Plotting
theta_dd_sim = np.array(theta_dd_sim)
theta_d_sim = np.array(theta_d_sim)
theta_sim = np.array(theta_sim)
x_dd_sim = np.array(x_dd_sim)
x_d_sim = np.array(x_d_sim)
x_sim = np.array(x_sim)

timeSteps = np.linspace(0, noOfSteps/(1/dt), num=noOfSteps, endpoint=False)

startTraj = 0
endTraj = 12000

# Plotting 
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6)

fig.set_figheight(26)
fig.set_figwidth(18)

ax1.plot(timeSteps[startTraj:endTraj], x_sim[startTraj:endTraj])
ax1.set_title("x")
ax2.plot(timeSteps[startTraj:endTraj], x_d_sim[startTraj:endTraj])
ax2.set_title("x_Dot")
ax3.plot(timeSteps[startTraj:endTraj], x_dd_sim[startTraj:endTraj])
ax3.set_title("x_DotDot")
#axs[1, 0].sharex(axs[0, 0])
ax4.plot(timeSteps[startTraj:endTraj], theta_sim[startTraj:endTraj])
ax4.set_title("theta")
ax5.plot(timeSteps[startTraj:endTraj], theta_d_sim[startTraj:endTraj])
ax5.set_title("theta_Dot")
ax6.plot(timeSteps[startTraj:endTraj], theta_dd_sim[startTraj:endTraj])
ax6.set_title("theta_DotDot")
fig.tight_layout()

# %%
# Force Input Plot 
forceIn = -0.2+0.5*np.sin(6*timeSteps)
fig, ax = plt.subplots()

fig.set_figheight(5)
fig.set_figwidth(18)

ax.plot(timeSteps[startTraj:endTraj], forceIn[startTraj:endTraj])
ax.set_title('A single plot')
# Out:
# Text(0.5, 1.0, 'A single plot')

# %%
st_Traj = 0
en_Traj = 8000 # 2307 # 9405

# Training Input (Standardized)
theta_sim_mean = theta_sim[st_Traj:en_Traj].mean()
theta_sim_stdev = theta_sim[st_Traj:en_Traj].std()

theta_d_sim_mean = theta_d_sim[st_Traj:en_Traj].mean()
theta_d_sim_stdev = theta_d_sim[st_Traj:en_Traj].std()

x_d_sim_mean = x_d_sim[st_Traj:en_Traj].mean()
x_d_sim_stdev = x_d_sim[st_Traj:en_Traj].std()

forceIn_mean = forceIn[st_Traj:en_Traj].mean()
forceIn_stdev = forceIn[st_Traj:en_Traj].std()  

# Training Output (Standardized)
theta_dd_sim_mean = theta_dd_sim[st_Traj:en_Traj].mean()
theta_dd_sim_stdev = theta_dd_sim[st_Traj:en_Traj].std()  

x_dd_sim_mean = x_dd_sim[st_Traj:en_Traj].mean()
x_dd_sim_stdev = x_dd_sim[st_Traj:en_Traj].std() 

X_train = np.stack(((theta_sim[st_Traj:en_Traj]-theta_sim_mean)/theta_sim_stdev,(theta_d_sim[st_Traj:en_Traj]-theta_d_sim_mean)/theta_d_sim_stdev,(x_d_sim[st_Traj:en_Traj]-x_d_sim_mean)/x_d_sim_stdev,(forceIn[st_Traj:en_Traj]-forceIn_mean)/forceIn_stdev), axis=1)

Y_train_theta = ((theta_dd_sim[st_Traj:en_Traj]-theta_dd_sim_mean)/theta_dd_sim_stdev)  # RMSE(A)
Y_train_x = ((x_dd_sim[st_Traj:en_Traj]-x_dd_sim_mean)/x_dd_sim_stdev)  # RMSE(V)

Y_train = np.stack((Y_train_theta, Y_train_x), axis=1) # For MultiOutput GP

# Testing Output (Standardized)

Y_test_theta = ((theta_dd_sim[en_Traj:]-theta_dd_sim_mean)/theta_dd_sim_stdev)  # RMSE(A)
Y_test_x = ((x_dd_sim[en_Traj:]-x_dd_sim_mean)/x_dd_sim_stdev)  # RMSE(V)

X_prior = np.stack(((theta_sim[:-1]-theta_sim_mean)/theta_sim_stdev,(theta_d_sim[:-1]-theta_d_sim_mean)/theta_d_sim_stdev,(x_d_sim[:-1]-x_d_sim_mean)/x_d_sim_stdev,(forceIn-forceIn_mean)/forceIn_stdev), axis=1) # Prior

# %%
# Numpy to tensors 
X_train = torch.from_numpy(X_train).float()
Y_train = torch.from_numpy(Y_train).float()
X_prior = torch.from_numpy(X_prior).float()

# Putting tensors on GPU
X_train = X_train.cuda()
Y_train = Y_train.cuda()
X_prior = X_prior.cuda()

# %% [markdown]
# # MultiOutput GP

# %%
class MultitaskGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(MultitaskGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.MultitaskMean(
            gpytorch.means.ConstantMean(), num_tasks=2
        )
        self.covar_module = gpytorch.kernels.MultitaskKernel(
            gpytorch.kernels.RBFKernel(ard_num_dims=4), num_tasks=2, rank=1
        )

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal(mean_x, covar_x)

    
likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=2, noise_constraint=gpytorch.constraints.GreaterThan(0.009))
#noise_prior=gpytorch.priors.SmoothedBoxPrior(0.15, 1.5, sigma=0.001))
model = MultitaskGPModel(X_train, Y_train, likelihood)

# putting on GPU
model = model.cuda()
likelihood = likelihood.cuda()

# %%
# Find optimal model hyperparameters
training_iter = 2000

model.train()
likelihood.train()

noiseTrain = np.zeros(training_iter)
lossTrain = np.zeros(training_iter)

# Use the adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)  # Includes GaussianLikelihood parameters

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(X_train)
    # Calc loss and backprop gradients
    loss = -mll(output, Y_train)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f  noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.likelihood.noise.item()
    ))
    noiseTrain[i] = model.likelihood.noise.item()
    lossTrain[i] = loss.item()
    optimizer.step()
# Out:
# Iter 1/2000 - Loss: 1.301  noise: 0.702
# Iter 2/2000 - Loss: 1.297  noise: 0.697
# Iter 3/2000 - Loss: 1.294  noise: 0.692
# Iter 4/2000 - Loss: 1.291  noise: 0.687
# Iter 5/2000 - Loss: 1.288  noise: 0.682
# Iter 6/2000 - Loss: 1.284  noise: 0.677
# Iter 7/2000 - Loss: 1.281  noise: 0.673
# Iter 8/2000 - Loss: 1.277  noise: 0.668
# Iter 9/2000 - Loss: 1.274  noise: 0.663
# Iter 10/2000 - Loss: 1.271  noise: 0.658
# Iter 11/2000 - Loss: 1.267  noise: 0.653
# Iter 12/2000 - Loss: 1.264  noise: 0.649
# Iter 13/2000 - Loss: 1.260  noise: 0.644
# Iter 14/2000 - Loss: 1.257  noise: 0.639
# Iter 15/2000 - Loss: 1.253  noise: 0.635
# Iter 16/2000 - Loss: 1.250  noise: 0.630
# Iter 17/2000 - Loss: 1.246  noise: 0.625
# Iter 18/2000 - Loss: 1.243  noise: 0.621
# Iter 19/2000 - Loss: 1.239  noise: 0.616
# Iter 20/2000 - Loss: 1.236  noise: 0.611
# Iter 21/2000 - Loss: 1.232  noise: 0.607
# Iter 22/2000 - Loss: 1.229  noise: 0.602
# Iter 23/2000 - Loss: 1.225  noise: 0.598
# Iter 24/2000 - Loss: 1.222  noise: 0.593
# Iter 25/2000 - Loss: 1.218  noise: 0.589
# Iter 26/2000 - Loss: 1.214  noise: 0.584
# Iter 27/2000 - Loss: 1.211  noise: 0.580
# Iter 28/2000 - Loss: 1.207  noise: 0.576
# Iter 29/2000 - Loss: 1.203  noise: 0.571
# Iter 30/2000 - Loss: 1.200  noise: 0.567
# Iter 31/2000 - Loss: 1.196  noise: 0.563
# Iter 32/2000 - Loss: 1.192  noise: 0.558
# Iter 33/2000 - Loss: 1.188  noise: 0.554
# Iter 34/2000 - Loss: 1.185  noise: 0.550
# Iter 35/2000 - Loss: 1.181  noise: 0.545
# Iter 36/2000 - Loss: 1.177  noise: 0.541
# Iter 37/2000 - Loss: 1.173  noise: 0.537
# Iter 38/2000 - Loss: 1.169  noise: 0.533
# Iter 39/2000 - Loss: 1.165  noise: 0.529
# Iter 40/2000 - Loss: 1.161  noise: 0.524
# Iter 41/2000 - Loss: 1.157  noise: 0.520
# Iter 42/2000 - Loss: 1.153  noise: 0.516
# Iter 43/2000 - Loss: 1.149  noise: 0.512
# Iter 44/2000 - Loss: 1.145  noise: 0.508
# Iter 45/2000 - Loss: 1.141  noise: 0.504
# Iter 46/2000 - Loss: 1.137  noise: 0.500
# Iter 47/2000 - Loss: 1.133  noise: 0.496
# Iter 48/2000 - Loss: 1.129  noise: 0.492
# Iter 49/2000 - Loss: 1.125  noise: 0.488
# Iter 50/2000 - Loss: 1.121  noise: 0.484
# Iter 51/2000 - Loss: 1.117  noise: 0.480
# Iter 52/2000 - Loss: 1.113  noise: 0.476
# Iter 53/2000 - Loss: 1.108  noise: 0.472
# Iter 54/2000 - Loss: 1.104  noise: 0.468
# Iter 55/2000 - Loss: 1.100  noise: 0.464
# Iter 56/2000 - Loss: 1.096  noise: 0.461
# Iter 57/2000 - Loss: 1.091  noise: 0.457
# Iter 58/2000 - Loss: 1.087  noise: 0.453
# Iter 59/2000 - Loss: 1.083  noise: 0.449
# Iter 60/2000 - Loss: 1.078  noise: 0.445
# Iter 61/2000 - Loss: 1.074  noise: 0.442
# Iter 62/2000 - Loss: 1.069  noise: 0.438
# Iter 63/2000 - Loss: 1.065  noise: 0.434
# Iter 64/2000 - Loss: 1.060  noise: 0.431
# Iter 65/2000 - Loss: 1.056  noise: 0.427
# Iter 66/2000 - Loss: 1.051  noise: 0.423
# Iter 67/2000 - Loss: 1.047  noise: 0.420
# Iter 68/2000 - Loss: 1.042  noise: 0.416
# Iter 69/2000 - Loss: 1.037  noise: 0.413
# Iter 70/2000 - Loss: 1.032  noise: 0.409
# Iter 71/2000 - Loss: 1.028  noise: 0.405
# Iter 72/2000 - Loss: 1.023  noise: 0.402
# Iter 73/2000 - Loss: 1.018  noise: 0.398
# Iter 74/2000 - Loss: 1.013  noise: 0.395
# Iter 75/2000 - Loss: 1.008  noise: 0.392
# Iter 76/2000 - Loss: 1.003  noise: 0.388
# Iter 77/2000 - Loss: 0.998  noise: 0.385
# Iter 78/2000 - Loss: 0.993  noise: 0.381
# Iter 79/2000 - Loss: 0.988  noise: 0.378
# Iter 80/2000 - Loss: 0.983  noise: 0.375
# Iter 81/2000 - Loss: 0.978  noise: 0.371
# Iter 82/2000 - Loss: 0.973  noise: 0.368
# Iter 83/2000 - Loss: 0.968  noise: 0.365
# Iter 84/2000 - Loss: 0.963  noise: 0.361
# Iter 85/2000 - Loss: 0.957  noise: 0.358
# Iter 86/2000 - Loss: 0.952  noise: 0.355
# Iter 87/2000 - Loss: 0.947  noise: 0.352
# Iter 88/2000 - Loss: 0.941  noise: 0.348
# Iter 89/2000 - Loss: 0.936  noise: 0.345
# Iter 90/2000 - Loss: 0.931  noise: 0.342
# Iter 91/2000 - Loss: 0.925  noise: 0.339
# Iter 92/2000 - Loss: 0.920  noise: 0.336
# Iter 93/2000 - Loss: 0.914  noise: 0.333
# Iter 94/2000 - Loss: 0.909  noise: 0.330
# Iter 95/2000 - Loss: 0.903  noise: 0.326
# Iter 96/2000 - Loss: 0.898  noise: 0.323
# Iter 97/2000 - Loss: 0.892  noise: 0.320
# Iter 98/2000 - Loss: 0.886  noise: 0.317
# Iter 99/2000 - Loss: 0.881  noise: 0.314
# Iter 100/2000 - Loss: 0.875  noise: 0.311
# Iter 101/2000 - Loss: 0.869  noise: 0.308
# Iter 102/2000 - Loss: 0.864  noise: 0.306
# Iter 103/2000 - Loss: 0.858  noise: 0.303
# Iter 104/2000 - Loss: 0.852  noise: 0.300
# Iter 105/2000 - Loss: 0.846  noise: 0.297
# Iter 106/2000 - Loss: 0.841  noise: 0.294
# Iter 107/2000 - Loss: 0.835  noise: 0.291
# Iter 108/2000 - Loss: 0.829  noise: 0.288
# Iter 109/2000 - Loss: 0.823  noise: 0.286
# Iter 110/2000 - Loss: 0.817  noise: 0.283
# Iter 111/2000 - Loss: 0.811  noise: 0.280
# Iter 112/2000 - Loss: 0.805  noise: 0.277
# Iter 113/2000 - Loss: 0.799  noise: 0.275
# Iter 114/2000 - Loss: 0.793  noise: 0.272
# Iter 115/2000 - Loss: 0.787  noise: 0.269
# Iter 116/2000 - Loss: 0.781  noise: 0.267
# Iter 117/2000 - Loss: 0.775  noise: 0.264
# Iter 118/2000 - Loss: 0.769  noise: 0.261
# Iter 119/2000 - Loss: 0.763  noise: 0.259
# Iter 120/2000 - Loss: 0.756  noise: 0.256
# Iter 121/2000 - Loss: 0.750  noise: 0.254
# Iter 122/2000 - Loss: 0.744  noise: 0.251
# Iter 123/2000 - Loss: 0.737  noise: 0.249
# Iter 124/2000 - Loss: 0.731  noise: 0.246
# Iter 125/2000 - Loss: 0.725  noise: 0.244
# Iter 126/2000 - Loss: 0.718  noise: 0.241
# Iter 127/2000 - Loss: 0.712  noise: 0.239
# Iter 128/2000 - Loss: 0.705  noise: 0.236
# Iter 129/2000 - Loss: 0.699  noise: 0.234
# Iter 130/2000 - Loss: 0.692  noise: 0.232
# Iter 131/2000 - Loss: 0.686  noise: 0.229
# Iter 132/2000 - Loss: 0.679  noise: 0.227
# Iter 133/2000 - Loss: 0.673  noise: 0.225
# Iter 134/2000 - Loss: 0.666  noise: 0.222
# Iter 135/2000 - Loss: 0.660  noise: 0.220
# Iter 136/2000 - Loss: 0.653  noise: 0.218
# Iter 137/2000 - Loss: 0.646  noise: 0.216
# Iter 138/2000 - Loss: 0.640  noise: 0.213
# Iter 139/2000 - Loss: 0.633  noise: 0.211
# Iter 140/2000 - Loss: 0.627  noise: 0.209
# Iter 141/2000 - Loss: 0.620  noise: 0.207
# Iter 142/2000 - Loss: 0.613  noise: 0.205
# Iter 143/2000 - Loss: 0.607  noise: 0.203
# Iter 144/2000 - Loss: 0.600  noise: 0.200
# Iter 145/2000 - Loss: 0.594  noise: 0.198
# Iter 146/2000 - Loss: 0.587  noise: 0.196
# Iter 147/2000 - Loss: 0.581  noise: 0.194
# Iter 148/2000 - Loss: 0.575  noise: 0.192
# Iter 149/2000 - Loss: 0.568  noise: 0.190
# Iter 150/2000 - Loss: 0.562  noise: 0.188
# Iter 151/2000 - Loss: 0.556  noise: 0.186
# Iter 152/2000 - Loss: 0.549  noise: 0.184
# Iter 153/2000 - Loss: 0.543  noise: 0.183
# Iter 154/2000 - Loss: 0.537  noise: 0.181
# Iter 155/2000 - Loss: 0.531  noise: 0.179
# Iter 156/2000 - Loss: 0.524  noise: 0.177
# Iter 157/2000 - Loss: 0.518  noise: 0.175
# Iter 158/2000 - Loss: 0.512  noise: 0.173
# Iter 159/2000 - Loss: 0.506  noise: 0.171
# Iter 160/2000 - Loss: 0.500  noise: 0.170
# Iter 161/2000 - Loss: 0.494  noise: 0.168
# Iter 162/2000 - Loss: 0.488  noise: 0.166
# Iter 163/2000 - Loss: 0.482  noise: 0.164
# Iter 164/2000 - Loss: 0.476  noise: 0.163
# Iter 165/2000 - Loss: 0.470  noise: 0.161
# Iter 166/2000 - Loss: 0.464  noise: 0.159
# Iter 167/2000 - Loss: 0.458  noise: 0.158
# Iter 168/2000 - Loss: 0.452  noise: 0.156
# Iter 169/2000 - Loss: 0.446  noise: 0.154
# Iter 170/2000 - Loss: 0.440  noise: 0.153
# Iter 171/2000 - Loss: 0.434  noise: 0.151
# Iter 172/2000 - Loss: 0.429  noise: 0.150
# Iter 173/2000 - Loss: 0.423  noise: 0.148
# Iter 174/2000 - Loss: 0.417  noise: 0.146
# Iter 175/2000 - Loss: 0.411  noise: 0.145
# Iter 176/2000 - Loss: 0.405  noise: 0.143
# Iter 177/2000 - Loss: 0.400  noise: 0.142
# Iter 178/2000 - Loss: 0.394  noise: 0.141
# Iter 179/2000 - Loss: 0.388  noise: 0.139
# Iter 180/2000 - Loss: 0.382  noise: 0.138
# Iter 181/2000 - Loss: 0.377  noise: 0.136
# Iter 182/2000 - Loss: 0.371  noise: 0.135
# Iter 183/2000 - Loss: 0.365  noise: 0.133
# Iter 184/2000 - Loss: 0.360  noise: 0.132
# Iter 185/2000 - Loss: 0.354  noise: 0.131
# Iter 186/2000 - Loss: 0.349  noise: 0.129
# Iter 187/2000 - Loss: 0.343  noise: 0.128
# Iter 188/2000 - Loss: 0.338  noise: 0.127
# Iter 189/2000 - Loss: 0.332  noise: 0.125
# Iter 190/2000 - Loss: 0.327  noise: 0.124
# Iter 191/2000 - Loss: 0.321  noise: 0.123
# Iter 192/2000 - Loss: 0.316  noise: 0.122
# Iter 193/2000 - Loss: 0.310  noise: 0.120
# Iter 194/2000 - Loss: 0.305  noise: 0.119
# Iter 195/2000 - Loss: 0.300  noise: 0.118
# Iter 196/2000 - Loss: 0.294  noise: 0.117
# Iter 197/2000 - Loss: 0.289  noise: 0.115
# Iter 198/2000 - Loss: 0.284  noise: 0.114
# Iter 199/2000 - Loss: 0.278  noise: 0.113
# Iter 200/2000 - Loss: 0.273  noise: 0.112
# Iter 201/2000 - Loss: 0.268  noise: 0.111
# Iter 202/2000 - Loss: 0.263  noise: 0.110
# Iter 203/2000 - Loss: 0.257  noise: 0.109
# Iter 204/2000 - Loss: 0.252  noise: 0.108
# Iter 205/2000 - Loss: 0.247  noise: 0.106
# Iter 206/2000 - Loss: 0.242  noise: 0.105
# Iter 207/2000 - Loss: 0.237  noise: 0.104
# Iter 208/2000 - Loss: 0.232  noise: 0.103
# Iter 209/2000 - Loss: 0.227  noise: 0.102
# Iter 210/2000 - Loss: 0.222  noise: 0.101
# Iter 211/2000 - Loss: 0.216  noise: 0.100
# Iter 212/2000 - Loss: 0.211  noise: 0.099
# Iter 213/2000 - Loss: 0.206  noise: 0.098
# Iter 214/2000 - Loss: 0.201  noise: 0.097
# Iter 215/2000 - Loss: 0.196  noise: 0.096
# Iter 216/2000 - Loss: 0.191  noise: 0.095
# Iter 217/2000 - Loss: 0.186  noise: 0.094
# Iter 218/2000 - Loss: 0.181  noise: 0.094
# Iter 219/2000 - Loss: 0.176  noise: 0.093
# Iter 220/2000 - Loss: 0.171  noise: 0.092
# Iter 221/2000 - Loss: 0.166  noise: 0.091
# Iter 222/2000 - Loss: 0.162  noise: 0.090
# Iter 223/2000 - Loss: 0.157  noise: 0.089
# Iter 224/2000 - Loss: 0.152  noise: 0.088
# Iter 225/2000 - Loss: 0.147  noise: 0.087
# Iter 226/2000 - Loss: 0.142  noise: 0.086
# Iter 227/2000 - Loss: 0.137  noise: 0.086
# Iter 228/2000 - Loss: 0.132  noise: 0.085
# Iter 229/2000 - Loss: 0.127  noise: 0.084
# Iter 230/2000 - Loss: 0.123  noise: 0.083
# Iter 231/2000 - Loss: 0.118  noise: 0.082
# Iter 232/2000 - Loss: 0.113  noise: 0.082
# Iter 233/2000 - Loss: 0.108  noise: 0.081
# Iter 234/2000 - Loss: 0.103  noise: 0.080
# Iter 235/2000 - Loss: 0.099  noise: 0.079
# Iter 236/2000 - Loss: 0.094  noise: 0.079
# Iter 237/2000 - Loss: 0.089  noise: 0.078
# Iter 238/2000 - Loss: 0.085  noise: 0.077
# Iter 239/2000 - Loss: 0.080  noise: 0.076
# Iter 240/2000 - Loss: 0.075  noise: 0.076
# Iter 241/2000 - Loss: 0.070  noise: 0.075
# Iter 242/2000 - Loss: 0.066  noise: 0.074
# Iter 243/2000 - Loss: 0.061  noise: 0.073
# Iter 244/2000 - Loss: 0.056  noise: 0.073
# Iter 245/2000 - Loss: 0.052  noise: 0.072
# Iter 246/2000 - Loss: 0.047  noise: 0.071
# Iter 247/2000 - Loss: 0.043  noise: 0.071
# Iter 248/2000 - Loss: 0.038  noise: 0.070
# Iter 249/2000 - Loss: 0.033  noise: 0.069
# Iter 250/2000 - Loss: 0.029  noise: 0.069
# Iter 251/2000 - Loss: 0.024  noise: 0.068
# Iter 252/2000 - Loss: 0.020  noise: 0.068
# Iter 253/2000 - Loss: 0.015  noise: 0.067
# Iter 254/2000 - Loss: 0.011  noise: 0.066
# Iter 255/2000 - Loss: 0.006  noise: 0.066
# Iter 256/2000 - Loss: 0.002  noise: 0.065
# Iter 257/2000 - Loss: -0.003  noise: 0.065
# Iter 258/2000 - Loss: -0.007  noise: 0.064
# Iter 259/2000 - Loss: -0.012  noise: 0.063
# Iter 260/2000 - Loss: -0.016  noise: 0.063
# Iter 261/2000 - Loss: -0.021  noise: 0.062
# Iter 262/2000 - Loss: -0.025  noise: 0.062
# Iter 263/2000 - Loss: -0.030  noise: 0.061
# Iter 264/2000 - Loss: -0.034  noise: 0.061
# Iter 265/2000 - Loss: -0.038  noise: 0.060
# Iter 266/2000 - Loss: -0.043  noise: 0.060
# Iter 267/2000 - Loss: -0.047  noise: 0.059
# Iter 268/2000 - Loss: -0.052  noise: 0.059
# Iter 269/2000 - Loss: -0.056  noise: 0.058
# Iter 270/2000 - Loss: -0.060  noise: 0.058
# Iter 271/2000 - Loss: -0.065  noise: 0.057
# Iter 272/2000 - Loss: -0.069  noise: 0.057
# Iter 273/2000 - Loss: -0.073  noise: 0.056
# Iter 274/2000 - Loss: -0.078  noise: 0.056
# Iter 275/2000 - Loss: -0.082  noise: 0.055
# Iter 276/2000 - Loss: -0.086  noise: 0.055
# Iter 277/2000 - Loss: -0.090  noise: 0.054
# Iter 278/2000 - Loss: -0.095  noise: 0.054
# Iter 279/2000 - Loss: -0.099  noise: 0.053
# Iter 280/2000 - Loss: -0.103  noise: 0.053
# Iter 281/2000 - Loss: -0.107  noise: 0.052
# Iter 282/2000 - Loss: -0.112  noise: 0.052
# Iter 283/2000 - Loss: -0.116  noise: 0.051
# Iter 284/2000 - Loss: -0.120  noise: 0.051
# Iter 285/2000 - Loss: -0.124  noise: 0.051
# Iter 286/2000 - Loss: -0.128  noise: 0.050
# Iter 287/2000 - Loss: -0.132  noise: 0.050
# Iter 288/2000 - Loss: -0.136  noise: 0.049
# Iter 289/2000 - Loss: -0.141  noise: 0.049
# Iter 290/2000 - Loss: -0.145  noise: 0.049
# Iter 291/2000 - Loss: -0.149  noise: 0.048
# Iter 292/2000 - Loss: -0.153  noise: 0.048
# Iter 293/2000 - Loss: -0.157  noise: 0.047
# Iter 294/2000 - Loss: -0.161  noise: 0.047
# Iter 295/2000 - Loss: -0.165  noise: 0.047
# Iter 296/2000 - Loss: -0.169  noise: 0.046
# Iter 297/2000 - Loss: -0.173  noise: 0.046
# Iter 298/2000 - Loss: -0.177  noise: 0.045
# Iter 299/2000 - Loss: -0.181  noise: 0.045
# Iter 300/2000 - Loss: -0.185  noise: 0.045
# Iter 301/2000 - Loss: -0.189  noise: 0.044
# Iter 302/2000 - Loss: -0.193  noise: 0.044
# Iter 303/2000 - Loss: -0.197  noise: 0.044
# Iter 304/2000 - Loss: -0.201  noise: 0.043
# Iter 305/2000 - Loss: -0.205  noise: 0.043
# Iter 306/2000 - Loss: -0.209  noise: 0.043
# Iter 307/2000 - Loss: -0.213  noise: 0.042
# Iter 308/2000 - Loss: -0.217  noise: 0.042
# Iter 309/2000 - Loss: -0.221  noise: 0.042
# Iter 310/2000 - Loss: -0.225  noise: 0.041
# Iter 311/2000 - Loss: -0.229  noise: 0.041
# Iter 312/2000 - Loss: -0.232  noise: 0.041
# Iter 313/2000 - Loss: -0.236  noise: 0.040
# Iter 314/2000 - Loss: -0.240  noise: 0.040
# Iter 315/2000 - Loss: -0.244  noise: 0.040
# Iter 316/2000 - Loss: -0.248  noise: 0.040
# Iter 317/2000 - Loss: -0.252  noise: 0.039
# Iter 318/2000 - Loss: -0.255  noise: 0.039
# Iter 319/2000 - Loss: -0.259  noise: 0.039
# Iter 320/2000 - Loss: -0.263  noise: 0.038
# Iter 321/2000 - Loss: -0.267  noise: 0.038
# Iter 322/2000 - Loss: -0.270  noise: 0.038
# Iter 323/2000 - Loss: -0.274  noise: 0.038
# Iter 324/2000 - Loss: -0.278  noise: 0.037
# Iter 325/2000 - Loss: -0.282  noise: 0.037
# Iter 326/2000 - Loss: -0.285  noise: 0.037
# Iter 327/2000 - Loss: -0.289  noise: 0.036
# Iter 328/2000 - Loss: -0.293  noise: 0.036
# Iter 329/2000 - Loss: -0.296  noise: 0.036
# Iter 330/2000 - Loss: -0.300  noise: 0.036
# Iter 331/2000 - Loss: -0.304  noise: 0.035
# Iter 332/2000 - Loss: -0.307  noise: 0.035
# Iter 333/2000 - Loss: -0.311  noise: 0.035
# Iter 334/2000 - Loss: -0.314  noise: 0.035
# Iter 335/2000 - Loss: -0.318  noise: 0.034
# Iter 336/2000 - Loss: -0.321  noise: 0.034
# Iter 337/2000 - Loss: -0.325  noise: 0.034
# Iter 338/2000 - Loss: -0.329  noise: 0.034
# Iter 339/2000 - Loss: -0.332  noise: 0.034
# Iter 340/2000 - Loss: -0.336  noise: 0.033
# Iter 341/2000 - Loss: -0.339  noise: 0.033
# Iter 342/2000 - Loss: -0.343  noise: 0.033
# Iter 343/2000 - Loss: -0.346  noise: 0.033
# Iter 344/2000 - Loss: -0.349  noise: 0.032
# Iter 345/2000 - Loss: -0.353  noise: 0.032
# Iter 346/2000 - Loss: -0.356  noise: 0.032
# Iter 347/2000 - Loss: -0.360  noise: 0.032
# Iter 348/2000 - Loss: -0.363  noise: 0.032
# Iter 349/2000 - Loss: -0.366  noise: 0.031
# Iter 350/2000 - Loss: -0.370  noise: 0.031
# Iter 351/2000 - Loss: -0.373  noise: 0.031
# Iter 352/2000 - Loss: -0.376  noise: 0.031
# Iter 353/2000 - Loss: -0.380  noise: 0.031
# Iter 354/2000 - Loss: -0.383  noise: 0.030
# Iter 355/2000 - Loss: -0.386  noise: 0.030
# Iter 356/2000 - Loss: -0.390  noise: 0.030
# Iter 357/2000 - Loss: -0.393  noise: 0.030
# Iter 358/2000 - Loss: -0.396  noise: 0.030
# Iter 359/2000 - Loss: -0.399  noise: 0.029
# Iter 360/2000 - Loss: -0.403  noise: 0.029
# Iter 361/2000 - Loss: -0.406  noise: 0.029
# Iter 362/2000 - Loss: -0.409  noise: 0.029
# Iter 363/2000 - Loss: -0.412  noise: 0.029
# Iter 364/2000 - Loss: -0.415  noise: 0.029
# Iter 365/2000 - Loss: -0.418  noise: 0.028
# Iter 366/2000 - Loss: -0.421  noise: 0.028
# Iter 367/2000 - Loss: -0.424  noise: 0.028
# Iter 368/2000 - Loss: -0.428  noise: 0.028
# Iter 369/2000 - Loss: -0.431  noise: 0.028
# Iter 370/2000 - Loss: -0.434  noise: 0.028
# Iter 371/2000 - Loss: -0.437  noise: 0.027
# Iter 372/2000 - Loss: -0.440  noise: 0.027
# Iter 373/2000 - Loss: -0.443  noise: 0.027
# Iter 374/2000 - Loss: -0.446  noise: 0.027
# Iter 375/2000 - Loss: -0.449  noise: 0.027
# Iter 376/2000 - Loss: -0.451  noise: 0.027
# Iter 377/2000 - Loss: -0.454  noise: 0.026
# Iter 378/2000 - Loss: -0.457  noise: 0.026
# Iter 379/2000 - Loss: -0.460  noise: 0.026
# Iter 380/2000 - Loss: -0.463  noise: 0.026
# Iter 381/2000 - Loss: -0.466  noise: 0.026
# Iter 382/2000 - Loss: -0.469  noise: 0.026
# Iter 383/2000 - Loss: -0.472  noise: 0.026
# Iter 384/2000 - Loss: -0.474  noise: 0.025
# Iter 385/2000 - Loss: -0.477  noise: 0.025
# Iter 386/2000 - Loss: -0.480  noise: 0.025
# Iter 387/2000 - Loss: -0.483  noise: 0.025
# Iter 388/2000 - Loss: -0.485  noise: 0.025
# Iter 389/2000 - Loss: -0.488  noise: 0.025
# Iter 390/2000 - Loss: -0.491  noise: 0.025
# Iter 391/2000 - Loss: -0.493  noise: 0.024
# Iter 392/2000 - Loss: -0.496  noise: 0.024
# Iter 393/2000 - Loss: -0.499  noise: 0.024
# Iter 394/2000 - Loss: -0.501  noise: 0.024
# Iter 395/2000 - Loss: -0.504  noise: 0.024
# Iter 396/2000 - Loss: -0.507  noise: 0.024
# Iter 397/2000 - Loss: -0.509  noise: 0.024
# Iter 398/2000 - Loss: -0.512  noise: 0.024
# Iter 399/2000 - Loss: -0.514  noise: 0.023
# Iter 400/2000 - Loss: -0.517  noise: 0.023
# Iter 401/2000 - Loss: -0.520  noise: 0.023
# Iter 402/2000 - Loss: -0.522  noise: 0.023
# Iter 403/2000 - Loss: -0.525  noise: 0.023
# Iter 404/2000 - Loss: -0.527  noise: 0.023
# Iter 405/2000 - Loss: -0.530  noise: 0.023
# Iter 406/2000 - Loss: -0.532  noise: 0.023
# Iter 407/2000 - Loss: -0.535  noise: 0.023
# Iter 408/2000 - Loss: -0.537  noise: 0.022
# Iter 409/2000 - Loss: -0.540  noise: 0.022
# Iter 410/2000 - Loss: -0.542  noise: 0.022
# Iter 411/2000 - Loss: -0.544  noise: 0.022
# Iter 412/2000 - Loss: -0.547  noise: 0.022
# Iter 413/2000 - Loss: -0.549  noise: 0.022
# Iter 414/2000 - Loss: -0.551  noise: 0.022
# Iter 415/2000 - Loss: -0.554  noise: 0.022
# Iter 416/2000 - Loss: -0.556  noise: 0.022
# Iter 417/2000 - Loss: -0.558  noise: 0.022
# Iter 418/2000 - Loss: -0.561  noise: 0.021
# Iter 419/2000 - Loss: -0.563  noise: 0.021
# Iter 420/2000 - Loss: -0.565  noise: 0.021
# Iter 421/2000 - Loss: -0.568  noise: 0.021
# Iter 422/2000 - Loss: -0.570  noise: 0.021
# Iter 423/2000 - Loss: -0.572  noise: 0.021
# Iter 424/2000 - Loss: -0.574  noise: 0.021
# Iter 425/2000 - Loss: -0.577  noise: 0.021
# Iter 426/2000 - Loss: -0.579  noise: 0.021
# Iter 427/2000 - Loss: -0.581  noise: 0.021
# Iter 428/2000 - Loss: -0.583  noise: 0.020
# Iter 429/2000 - Loss: -0.585  noise: 0.020
# Iter 430/2000 - Loss: -0.587  noise: 0.020
# Iter 431/2000 - Loss: -0.590  noise: 0.020
# Iter 432/2000 - Loss: -0.592  noise: 0.020
# Iter 433/2000 - Loss: -0.594  noise: 0.020
# Iter 434/2000 - Loss: -0.596  noise: 0.020
# Iter 435/2000 - Loss: -0.598  noise: 0.020
# Iter 436/2000 - Loss: -0.600  noise: 0.020
# Iter 437/2000 - Loss: -0.602  noise: 0.020
# Iter 438/2000 - Loss: -0.604  noise: 0.020
# Iter 439/2000 - Loss: -0.606  noise: 0.020
# Iter 440/2000 - Loss: -0.608  noise: 0.020
# Iter 441/2000 - Loss: -0.610  noise: 0.019
# Iter 442/2000 - Loss: -0.612  noise: 0.019
# Iter 443/2000 - Loss: -0.614  noise: 0.019
# Iter 444/2000 - Loss: -0.616  noise: 0.019
# Iter 445/2000 - Loss: -0.618  noise: 0.019
# Iter 446/2000 - Loss: -0.620  noise: 0.019
# Iter 447/2000 - Loss: -0.622  noise: 0.019
# Iter 448/2000 - Loss: -0.624  noise: 0.019
# Iter 449/2000 - Loss: -0.626  noise: 0.019
# Iter 450/2000 - Loss: -0.628  noise: 0.019
# Iter 451/2000 - Loss: -0.630  noise: 0.019
# Iter 452/2000 - Loss: -0.632  noise: 0.019
# Iter 453/2000 - Loss: -0.634  noise: 0.019
# Iter 454/2000 - Loss: -0.635  noise: 0.018
# Iter 455/2000 - Loss: -0.637  noise: 0.018
# Iter 456/2000 - Loss: -0.639  noise: 0.018
# Iter 457/2000 - Loss: -0.641  noise: 0.018
# Iter 458/2000 - Loss: -0.643  noise: 0.018
# Iter 459/2000 - Loss: -0.645  noise: 0.018
# Iter 460/2000 - Loss: -0.646  noise: 0.018
# Iter 461/2000 - Loss: -0.648  noise: 0.018
# Iter 462/2000 - Loss: -0.650  noise: 0.018
# Iter 463/2000 - Loss: -0.652  noise: 0.018
# Iter 464/2000 - Loss: -0.653  noise: 0.018
# Iter 465/2000 - Loss: -0.655  noise: 0.018
# Iter 466/2000 - Loss: -0.657  noise: 0.018
# Iter 467/2000 - Loss: -0.659  noise: 0.018
# Iter 468/2000 - Loss: -0.660  noise: 0.018
# Iter 469/2000 - Loss: -0.662  noise: 0.018
# Iter 470/2000 - Loss: -0.664  noise: 0.017
# Iter 471/2000 - Loss: -0.665  noise: 0.017
# Iter 472/2000 - Loss: -0.667  noise: 0.017
# Iter 473/2000 - Loss: -0.669  noise: 0.017
# Iter 474/2000 - Loss: -0.670  noise: 0.017
# Iter 475/2000 - Loss: -0.672  noise: 0.017
# Iter 476/2000 - Loss: -0.673  noise: 0.017
# Iter 477/2000 - Loss: -0.675  noise: 0.017
# Iter 478/2000 - Loss: -0.677  noise: 0.017
# Iter 479/2000 - Loss: -0.678  noise: 0.017
# Iter 480/2000 - Loss: -0.680  noise: 0.017
# Iter 481/2000 - Loss: -0.681  noise: 0.017
# Iter 482/2000 - Loss: -0.683  noise: 0.017
# Iter 483/2000 - Loss: -0.684  noise: 0.017
# Iter 484/2000 - Loss: -0.686  noise: 0.017
# Iter 485/2000 - Loss: -0.688  noise: 0.017
# Iter 486/2000 - Loss: -0.689  noise: 0.017
# Iter 487/2000 - Loss: -0.691  noise: 0.017
# Iter 488/2000 - Loss: -0.692  noise: 0.017
# Iter 489/2000 - Loss: -0.693  noise: 0.016
# Iter 490/2000 - Loss: -0.695  noise: 0.016
# Iter 491/2000 - Loss: -0.696  noise: 0.016
# Iter 492/2000 - Loss: -0.698  noise: 0.016
# Iter 493/2000 - Loss: -0.699  noise: 0.016
# Iter 494/2000 - Loss: -0.701  noise: 0.016
# Iter 495/2000 - Loss: -0.702  noise: 0.016
# Iter 496/2000 - Loss: -0.704  noise: 0.016
# Iter 497/2000 - Loss: -0.705  noise: 0.016
# Iter 498/2000 - Loss: -0.706  noise: 0.016
# Iter 499/2000 - Loss: -0.708  noise: 0.016
# Iter 500/2000 - Loss: -0.709  noise: 0.016
# Iter 501/2000 - Loss: -0.711  noise: 0.016
# Iter 502/2000 - Loss: -0.712  noise: 0.016
# Iter 503/2000 - Loss: -0.713  noise: 0.016
# Iter 504/2000 - Loss: -0.715  noise: 0.016
# Iter 505/2000 - Loss: -0.716  noise: 0.016
# Iter 506/2000 - Loss: -0.717  noise: 0.016
# Iter 507/2000 - Loss: -0.719  noise: 0.016
# Iter 508/2000 - Loss: -0.720  noise: 0.016
# Iter 509/2000 - Loss: -0.721  noise: 0.016
# Iter 510/2000 - Loss: -0.723  noise: 0.016
# Iter 511/2000 - Loss: -0.724  noise: 0.015
# Iter 512/2000 - Loss: -0.725  noise: 0.015
# Iter 513/2000 - Loss: -0.726  noise: 0.015
# Iter 514/2000 - Loss: -0.728  noise: 0.015
# Iter 515/2000 - Loss: -0.729  noise: 0.015
# Iter 516/2000 - Loss: -0.730  noise: 0.015
# Iter 517/2000 - Loss: -0.731  noise: 0.015
# Iter 518/2000 - Loss: -0.733  noise: 0.015
# Iter 519/2000 - Loss: -0.734  noise: 0.015
# Iter 520/2000 - Loss: -0.735  noise: 0.015
# Iter 521/2000 - Loss: -0.736  noise: 0.015
# Iter 522/2000 - Loss: -0.737  noise: 0.015
# Iter 523/2000 - Loss: -0.739  noise: 0.015
# Iter 524/2000 - Loss: -0.740  noise: 0.015
# Iter 525/2000 - Loss: -0.741  noise: 0.015
# Iter 526/2000 - Loss: -0.742  noise: 0.015
# Iter 527/2000 - Loss: -0.743  noise: 0.015
# Iter 528/2000 - Loss: -0.745  noise: 0.015
# Iter 529/2000 - Loss: -0.746  noise: 0.015
# Iter 530/2000 - Loss: -0.747  noise: 0.015
# Iter 531/2000 - Loss: -0.748  noise: 0.015
# Iter 532/2000 - Loss: -0.749  noise: 0.015
# Iter 533/2000 - Loss: -0.750  noise: 0.015
# Iter 534/2000 - Loss: -0.751  noise: 0.015
# Iter 535/2000 - Loss: -0.752  noise: 0.015
# Iter 536/2000 - Loss: -0.754  noise: 0.015
# Iter 537/2000 - Loss: -0.755  noise: 0.015
# Iter 538/2000 - Loss: -0.756  noise: 0.015
# Iter 539/2000 - Loss: -0.757  noise: 0.015
# Iter 540/2000 - Loss: -0.758  noise: 0.014
# Iter 541/2000 - Loss: -0.759  noise: 0.014
# Iter 542/2000 - Loss: -0.760  noise: 0.014
# Iter 543/2000 - Loss: -0.761  noise: 0.014
# Iter 544/2000 - Loss: -0.762  noise: 0.014
# Iter 545/2000 - Loss: -0.763  noise: 0.014
# Iter 546/2000 - Loss: -0.764  noise: 0.014
# Iter 547/2000 - Loss: -0.765  noise: 0.014
# Iter 548/2000 - Loss: -0.766  noise: 0.014
# Iter 549/2000 - Loss: -0.767  noise: 0.014
# Iter 550/2000 - Loss: -0.768  noise: 0.014
# Iter 551/2000 - Loss: -0.769  noise: 0.014
# Iter 552/2000 - Loss: -0.770  noise: 0.014
# Iter 553/2000 - Loss: -0.771  noise: 0.014
# Iter 554/2000 - Loss: -0.772  noise: 0.014
# Iter 555/2000 - Loss: -0.773  noise: 0.014
# Iter 556/2000 - Loss: -0.774  noise: 0.014
# Iter 557/2000 - Loss: -0.775  noise: 0.014
# Iter 558/2000 - Loss: -0.776  noise: 0.014
# Iter 559/2000 - Loss: -0.777  noise: 0.014
# Iter 560/2000 - Loss: -0.778  noise: 0.014
# Iter 561/2000 - Loss: -0.779  noise: 0.014
# Iter 562/2000 - Loss: -0.780  noise: 0.014
# Iter 563/2000 - Loss: -0.781  noise: 0.014
# Iter 564/2000 - Loss: -0.782  noise: 0.014
# Iter 565/2000 - Loss: -0.783  noise: 0.014
# Iter 566/2000 - Loss: -0.784  noise: 0.014
# Iter 567/2000 - Loss: -0.785  noise: 0.014
# Iter 568/2000 - Loss: -0.785  noise: 0.014
# Iter 569/2000 - Loss: -0.786  noise: 0.014
# Iter 570/2000 - Loss: -0.787  noise: 0.014
# Iter 571/2000 - Loss: -0.788  noise: 0.014
# Iter 572/2000 - Loss: -0.789  noise: 0.014
# Iter 573/2000 - Loss: -0.790  noise: 0.014
# Iter 574/2000 - Loss: -0.791  noise: 0.014
# Iter 575/2000 - Loss: -0.792  noise: 0.014
# Iter 576/2000 - Loss: -0.792  noise: 0.014
# Iter 577/2000 - Loss: -0.793  noise: 0.013
# Iter 578/2000 - Loss: -0.794  noise: 0.013
# Iter 579/2000 - Loss: -0.795  noise: 0.013
# Iter 580/2000 - Loss: -0.796  noise: 0.013
# Iter 581/2000 - Loss: -0.797  noise: 0.013
# Iter 582/2000 - Loss: -0.798  noise: 0.013
# Iter 583/2000 - Loss: -0.798  noise: 0.013
# Iter 584/2000 - Loss: -0.799  noise: 0.013
# Iter 585/2000 - Loss: -0.800  noise: 0.013
# Iter 586/2000 - Loss: -0.801  noise: 0.013
# Iter 587/2000 - Loss: -0.802  noise: 0.013
# Iter 588/2000 - Loss: -0.802  noise: 0.013
# Iter 589/2000 - Loss: -0.803  noise: 0.013
# Iter 590/2000 - Loss: -0.804  noise: 0.013
# Iter 591/2000 - Loss: -0.805  noise: 0.013
# Iter 592/2000 - Loss: -0.806  noise: 0.013
# Iter 593/2000 - Loss: -0.806  noise: 0.013
# Iter 594/2000 - Loss: -0.807  noise: 0.013
# Iter 595/2000 - Loss: -0.808  noise: 0.013
# Iter 596/2000 - Loss: -0.809  noise: 0.013
# Iter 597/2000 - Loss: -0.809  noise: 0.013
# Iter 598/2000 - Loss: -0.810  noise: 0.013
# Iter 599/2000 - Loss: -0.811  noise: 0.013
# Iter 600/2000 - Loss: -0.812  noise: 0.013
# Iter 601/2000 - Loss: -0.812  noise: 0.013
# Iter 602/2000 - Loss: -0.813  noise: 0.013
# Iter 603/2000 - Loss: -0.814  noise: 0.013
# Iter 604/2000 - Loss: -0.815  noise: 0.013
# Iter 605/2000 - Loss: -0.815  noise: 0.013
# Iter 606/2000 - Loss: -0.816  noise: 0.013
# Iter 607/2000 - Loss: -0.817  noise: 0.013
# Iter 608/2000 - Loss: -0.817  noise: 0.013
# Iter 609/2000 - Loss: -0.818  noise: 0.013
# Iter 610/2000 - Loss: -0.819  noise: 0.013
# Iter 611/2000 - Loss: -0.820  noise: 0.013
# Iter 612/2000 - Loss: -0.820  noise: 0.013
# Iter 613/2000 - Loss: -0.821  noise: 0.013
# Iter 614/2000 - Loss: -0.822  noise: 0.013
# Iter 615/2000 - Loss: -0.822  noise: 0.013
# Iter 616/2000 - Loss: -0.823  noise: 0.013
# Iter 617/2000 - Loss: -0.824  noise: 0.013
# Iter 618/2000 - Loss: -0.824  noise: 0.013
# Iter 619/2000 - Loss: -0.825  noise: 0.013
# Iter 620/2000 - Loss: -0.826  noise: 0.013
# Iter 621/2000 - Loss: -0.826  noise: 0.013
# Iter 622/2000 - Loss: -0.827  noise: 0.013
# Iter 623/2000 - Loss: -0.828  noise: 0.013
# Iter 624/2000 - Loss: -0.828  noise: 0.013
# Iter 625/2000 - Loss: -0.829  noise: 0.013
# Iter 626/2000 - Loss: -0.830  noise: 0.013
# Iter 627/2000 - Loss: -0.830  noise: 0.013
# Iter 628/2000 - Loss: -0.831  noise: 0.013
# Iter 629/2000 - Loss: -0.831  noise: 0.012
# Iter 630/2000 - Loss: -0.832  noise: 0.012
# Iter 631/2000 - Loss: -0.833  noise: 0.012
# Iter 632/2000 - Loss: -0.833  noise: 0.012
# Iter 633/2000 - Loss: -0.834  noise: 0.012
# Iter 634/2000 - Loss: -0.834  noise: 0.012
# Iter 635/2000 - Loss: -0.835  noise: 0.012
# Iter 636/2000 - Loss: -0.836  noise: 0.012
# Iter 637/2000 - Loss: -0.836  noise: 0.012
# Iter 638/2000 - Loss: -0.837  noise: 0.012
# Iter 639/2000 - Loss: -0.837  noise: 0.012
# Iter 640/2000 - Loss: -0.838  noise: 0.012
# Iter 641/2000 - Loss: -0.839  noise: 0.012
# Iter 642/2000 - Loss: -0.839  noise: 0.012
# Iter 643/2000 - Loss: -0.840  noise: 0.012
# Iter 644/2000 - Loss: -0.840  noise: 0.012
# Iter 645/2000 - Loss: -0.841  noise: 0.012
# Iter 646/2000 - Loss: -0.841  noise: 0.012
# Iter 647/2000 - Loss: -0.842  noise: 0.012
# Iter 648/2000 - Loss: -0.843  noise: 0.012
# Iter 649/2000 - Loss: -0.843  noise: 0.012
# Iter 650/2000 - Loss: -0.844  noise: 0.012
# Iter 651/2000 - Loss: -0.844  noise: 0.012
# Iter 652/2000 - Loss: -0.845  noise: 0.012
# Iter 653/2000 - Loss: -0.845  noise: 0.012
# Iter 654/2000 - Loss: -0.846  noise: 0.012
# Iter 655/2000 - Loss: -0.846  noise: 0.012
# Iter 656/2000 - Loss: -0.847  noise: 0.012
# Iter 657/2000 - Loss: -0.848  noise: 0.012
# Iter 658/2000 - Loss: -0.848  noise: 0.012
# Iter 659/2000 - Loss: -0.849  noise: 0.012
# Iter 660/2000 - Loss: -0.849  noise: 0.012
# Iter 661/2000 - Loss: -0.850  noise: 0.012
# Iter 662/2000 - Loss: -0.850  noise: 0.012
# Iter 663/2000 - Loss: -0.851  noise: 0.012
# Iter 664/2000 - Loss: -0.851  noise: 0.012
# Iter 665/2000 - Loss: -0.852  noise: 0.012
# Iter 666/2000 - Loss: -0.852  noise: 0.012
# Iter 667/2000 - Loss: -0.853  noise: 0.012
# Iter 668/2000 - Loss: -0.853  noise: 0.012
# Iter 669/2000 - Loss: -0.854  noise: 0.012
# Iter 670/2000 - Loss: -0.854  noise: 0.012
# Iter 671/2000 - Loss: -0.855  noise: 0.012
# Iter 672/2000 - Loss: -0.855  noise: 0.012
# Iter 673/2000 - Loss: -0.856  noise: 0.012
# Iter 674/2000 - Loss: -0.856  noise: 0.012
# Iter 675/2000 - Loss: -0.857  noise: 0.012
# Iter 676/2000 - Loss: -0.857  noise: 0.012
# Iter 677/2000 - Loss: -0.858  noise: 0.012
# Iter 678/2000 - Loss: -0.858  noise: 0.012
# Iter 679/2000 - Loss: -0.858  noise: 0.012
# Iter 680/2000 - Loss: -0.859  noise: 0.012
# Iter 681/2000 - Loss: -0.859  noise: 0.012
# Iter 682/2000 - Loss: -0.860  noise: 0.012
# Iter 683/2000 - Loss: -0.860  noise: 0.012
# Iter 684/2000 - Loss: -0.861  noise: 0.012
# Iter 685/2000 - Loss: -0.861  noise: 0.012
# Iter 686/2000 - Loss: -0.862  noise: 0.012
# Iter 687/2000 - Loss: -0.862  noise: 0.012
# Iter 688/2000 - Loss: -0.863  noise: 0.012
# Iter 689/2000 - Loss: -0.863  noise: 0.012
# Iter 690/2000 - Loss: -0.863  noise: 0.012
# Iter 691/2000 - Loss: -0.864  noise: 0.012
# Iter 692/2000 - Loss: -0.864  noise: 0.012
# Iter 693/2000 - Loss: -0.865  noise: 0.012
# Iter 694/2000 - Loss: -0.865  noise: 0.012
# Iter 695/2000 - Loss: -0.866  noise: 0.012
# Iter 696/2000 - Loss: -0.866  noise: 0.012
# Iter 697/2000 - Loss: -0.866  noise: 0.012
# Iter 698/2000 - Loss: -0.867  noise: 0.012
# Iter 699/2000 - Loss: -0.867  noise: 0.012
# Iter 700/2000 - Loss: -0.868  noise: 0.012
# Iter 701/2000 - Loss: -0.868  noise: 0.012
# Iter 702/2000 - Loss: -0.869  noise: 0.012
# Iter 703/2000 - Loss: -0.869  noise: 0.012
# Iter 704/2000 - Loss: -0.869  noise: 0.012
# Iter 705/2000 - Loss: -0.870  noise: 0.012
# Iter 706/2000 - Loss: -0.870  noise: 0.012
# Iter 707/2000 - Loss: -0.871  noise: 0.012
# Iter 708/2000 - Loss: -0.871  noise: 0.012
# Iter 709/2000 - Loss: -0.871  noise: 0.012
# Iter 710/2000 - Loss: -0.872  noise: 0.011
# Iter 711/2000 - Loss: -0.872  noise: 0.011
# Iter 712/2000 - Loss: -0.873  noise: 0.011
# Iter 713/2000 - Loss: -0.873  noise: 0.011
# Iter 714/2000 - Loss: -0.873  noise: 0.011
# Iter 715/2000 - Loss: -0.874  noise: 0.011
# Iter 716/2000 - Loss: -0.874  noise: 0.011
# Iter 717/2000 - Loss: -0.874  noise: 0.011
# Iter 718/2000 - Loss: -0.875  noise: 0.011
# Iter 719/2000 - Loss: -0.875  noise: 0.011
# Iter 720/2000 - Loss: -0.876  noise: 0.011
# Iter 721/2000 - Loss: -0.876  noise: 0.011
# Iter 722/2000 - Loss: -0.876  noise: 0.011
# Iter 723/2000 - Loss: -0.877  noise: 0.011
# Iter 724/2000 - Loss: -0.877  noise: 0.011
# Iter 725/2000 - Loss: -0.877  noise: 0.011
# Iter 726/2000 - Loss: -0.878  noise: 0.011
# Iter 727/2000 - Loss: -0.878  noise: 0.011
# Iter 728/2000 - Loss: -0.879  noise: 0.011
# Iter 729/2000 - Loss: -0.879  noise: 0.011
# Iter 730/2000 - Loss: -0.879  noise: 0.011
# Iter 731/2000 - Loss: -0.880  noise: 0.011
# Iter 732/2000 - Loss: -0.880  noise: 0.011
# Iter 733/2000 - Loss: -0.880  noise: 0.011
# Iter 734/2000 - Loss: -0.881  noise: 0.011
# Iter 735/2000 - Loss: -0.881  noise: 0.011
# Iter 736/2000 - Loss: -0.881  noise: 0.011
# Iter 737/2000 - Loss: -0.882  noise: 0.011
# Iter 738/2000 - Loss: -0.882  noise: 0.011
# Iter 739/2000 - Loss: -0.882  noise: 0.011
# Iter 740/2000 - Loss: -0.883  noise: 0.011
# Iter 741/2000 - Loss: -0.883  noise: 0.011
# Iter 742/2000 - Loss: -0.883  noise: 0.011
# Iter 743/2000 - Loss: -0.884  noise: 0.011
# Iter 744/2000 - Loss: -0.884  noise: 0.011
# Iter 745/2000 - Loss: -0.884  noise: 0.011
# Iter 746/2000 - Loss: -0.885  noise: 0.011
# Iter 747/2000 - Loss: -0.885  noise: 0.011
# Iter 748/2000 - Loss: -0.885  noise: 0.011
# Iter 749/2000 - Loss: -0.886  noise: 0.011
# Iter 750/2000 - Loss: -0.886  noise: 0.011
# Iter 751/2000 - Loss: -0.886  noise: 0.011
# Iter 752/2000 - Loss: -0.887  noise: 0.011
# Iter 753/2000 - Loss: -0.887  noise: 0.011
# Iter 754/2000 - Loss: -0.887  noise: 0.011
# Iter 755/2000 - Loss: -0.888  noise: 0.011
# Iter 756/2000 - Loss: -0.888  noise: 0.011
# Iter 757/2000 - Loss: -0.888  noise: 0.011
# Iter 758/2000 - Loss: -0.889  noise: 0.011
# Iter 759/2000 - Loss: -0.889  noise: 0.011
# Iter 760/2000 - Loss: -0.889  noise: 0.011
# Iter 761/2000 - Loss: -0.889  noise: 0.011
# Iter 762/2000 - Loss: -0.890  noise: 0.011
# Iter 763/2000 - Loss: -0.890  noise: 0.011
# Iter 764/2000 - Loss: -0.890  noise: 0.011
# Iter 765/2000 - Loss: -0.891  noise: 0.011
# Iter 766/2000 - Loss: -0.891  noise: 0.011
# Iter 767/2000 - Loss: -0.891  noise: 0.011
# Iter 768/2000 - Loss: -0.892  noise: 0.011
# Iter 769/2000 - Loss: -0.892  noise: 0.011
# Iter 770/2000 - Loss: -0.892  noise: 0.011
# Iter 771/2000 - Loss: -0.892  noise: 0.011
# Iter 772/2000 - Loss: -0.893  noise: 0.011
# Iter 773/2000 - Loss: -0.893  noise: 0.011
# Iter 774/2000 - Loss: -0.893  noise: 0.011
# Iter 775/2000 - Loss: -0.894  noise: 0.011
# Iter 776/2000 - Loss: -0.894  noise: 0.011
# Iter 777/2000 - Loss: -0.894  noise: 0.011
# Iter 778/2000 - Loss: -0.894  noise: 0.011
# Iter 779/2000 - Loss: -0.895  noise: 0.011
# Iter 780/2000 - Loss: -0.895  noise: 0.011
# Iter 781/2000 - Loss: -0.895  noise: 0.011
# Iter 782/2000 - Loss: -0.896  noise: 0.011
# Iter 783/2000 - Loss: -0.896  noise: 0.011
# Iter 784/2000 - Loss: -0.896  noise: 0.011
# Iter 785/2000 - Loss: -0.896  noise: 0.011
# Iter 786/2000 - Loss: -0.897  noise: 0.011
# Iter 787/2000 - Loss: -0.897  noise: 0.011
# Iter 788/2000 - Loss: -0.897  noise: 0.011
# Iter 789/2000 - Loss: -0.898  noise: 0.011
# Iter 790/2000 - Loss: -0.898  noise: 0.011
# Iter 791/2000 - Loss: -0.898  noise: 0.011
# Iter 792/2000 - Loss: -0.898  noise: 0.011
# Iter 793/2000 - Loss: -0.899  noise: 0.011
# Iter 794/2000 - Loss: -0.899  noise: 0.011
# Iter 795/2000 - Loss: -0.899  noise: 0.011
# Iter 796/2000 - Loss: -0.899  noise: 0.011
# Iter 797/2000 - Loss: -0.900  noise: 0.011
# Iter 798/2000 - Loss: -0.900  noise: 0.011
# Iter 799/2000 - Loss: -0.900  noise: 0.011
# Iter 800/2000 - Loss: -0.900  noise: 0.011
# Iter 801/2000 - Loss: -0.901  noise: 0.011
# Iter 802/2000 - Loss: -0.901  noise: 0.011
# Iter 803/2000 - Loss: -0.901  noise: 0.011
# Iter 804/2000 - Loss: -0.901  noise: 0.011
# Iter 805/2000 - Loss: -0.902  noise: 0.011
# Iter 806/2000 - Loss: -0.902  noise: 0.011
# Iter 807/2000 - Loss: -0.902  noise: 0.011
# Iter 808/2000 - Loss: -0.902  noise: 0.011
# Iter 809/2000 - Loss: -0.903  noise: 0.011
# Iter 810/2000 - Loss: -0.903  noise: 0.011
# Iter 811/2000 - Loss: -0.903  noise: 0.011
# Iter 812/2000 - Loss: -0.903  noise: 0.011
# Iter 813/2000 - Loss: -0.904  noise: 0.011
# Iter 814/2000 - Loss: -0.904  noise: 0.011
# Iter 815/2000 - Loss: -0.904  noise: 0.011
# Iter 816/2000 - Loss: -0.904  noise: 0.011
# Iter 817/2000 - Loss: -0.905  noise: 0.011
# Iter 818/2000 - Loss: -0.905  noise: 0.011
# Iter 819/2000 - Loss: -0.905  noise: 0.011
# Iter 820/2000 - Loss: -0.905  noise: 0.011
# Iter 821/2000 - Loss: -0.906  noise: 0.011
# Iter 822/2000 - Loss: -0.906  noise: 0.011
# Iter 823/2000 - Loss: -0.906  noise: 0.011
# Iter 824/2000 - Loss: -0.906  noise: 0.011
# Iter 825/2000 - Loss: -0.906  noise: 0.011
# Iter 826/2000 - Loss: -0.907  noise: 0.011
# Iter 827/2000 - Loss: -0.907  noise: 0.011
# Iter 828/2000 - Loss: -0.907  noise: 0.011
# Iter 829/2000 - Loss: -0.907  noise: 0.011
# Iter 830/2000 - Loss: -0.908  noise: 0.011
# Iter 831/2000 - Loss: -0.908  noise: 0.011
# Iter 832/2000 - Loss: -0.908  noise: 0.011
# Iter 833/2000 - Loss: -0.908  noise: 0.011
# Iter 834/2000 - Loss: -0.908  noise: 0.011
# Iter 835/2000 - Loss: -0.909  noise: 0.011
# Iter 836/2000 - Loss: -0.909  noise: 0.011
# Iter 837/2000 - Loss: -0.909  noise: 0.011
# Iter 838/2000 - Loss: -0.909  noise: 0.011
# Iter 839/2000 - Loss: -0.910  noise: 0.011
# Iter 840/2000 - Loss: -0.910  noise: 0.011
# Iter 841/2000 - Loss: -0.910  noise: 0.011
# Iter 842/2000 - Loss: -0.910  noise: 0.011
# Iter 843/2000 - Loss: -0.910  noise: 0.011
# Iter 844/2000 - Loss: -0.911  noise: 0.011
# Iter 845/2000 - Loss: -0.911  noise: 0.011
# Iter 846/2000 - Loss: -0.911  noise: 0.011
# Iter 847/2000 - Loss: -0.911  noise: 0.011
# Iter 848/2000 - Loss: -0.911  noise: 0.011
# Iter 849/2000 - Loss: -0.912  noise: 0.011
# Iter 850/2000 - Loss: -0.912  noise: 0.011
# Iter 851/2000 - Loss: -0.912  noise: 0.011
# Iter 852/2000 - Loss: -0.912  noise: 0.011
# Iter 853/2000 - Loss: -0.913  noise: 0.011
# Iter 854/2000 - Loss: -0.913  noise: 0.011
# Iter 855/2000 - Loss: -0.913  noise: 0.011
# Iter 856/2000 - Loss: -0.913  noise: 0.011
# Iter 857/2000 - Loss: -0.913  noise: 0.011
# Iter 858/2000 - Loss: -0.914  noise: 0.011
# Iter 859/2000 - Loss: -0.914  noise: 0.011
# Iter 860/2000 - Loss: -0.914  noise: 0.011
# Iter 861/2000 - Loss: -0.914  noise: 0.011
# Iter 862/2000 - Loss: -0.914  noise: 0.011
# Iter 863/2000 - Loss: -0.914  noise: 0.011
# Iter 864/2000 - Loss: -0.915  noise: 0.011
# Iter 865/2000 - Loss: -0.915  noise: 0.011
# Iter 866/2000 - Loss: -0.915  noise: 0.011
# Iter 867/2000 - Loss: -0.915  noise: 0.011
# Iter 868/2000 - Loss: -0.915  noise: 0.010
# Iter 869/2000 - Loss: -0.916  noise: 0.010
# Iter 870/2000 - Loss: -0.916  noise: 0.010
# Iter 871/2000 - Loss: -0.916  noise: 0.010
# Iter 872/2000 - Loss: -0.916  noise: 0.010
# Iter 873/2000 - Loss: -0.916  noise: 0.010
# Iter 874/2000 - Loss: -0.917  noise: 0.010
# Iter 875/2000 - Loss: -0.917  noise: 0.010
# Iter 876/2000 - Loss: -0.917  noise: 0.010
# Iter 877/2000 - Loss: -0.917  noise: 0.010
# Iter 878/2000 - Loss: -0.917  noise: 0.010
# Iter 879/2000 - Loss: -0.918  noise: 0.010
# Iter 880/2000 - Loss: -0.918  noise: 0.010
# Iter 881/2000 - Loss: -0.918  noise: 0.010
# Iter 882/2000 - Loss: -0.918  noise: 0.010
# Iter 883/2000 - Loss: -0.918  noise: 0.010
# Iter 884/2000 - Loss: -0.918  noise: 0.010
# Iter 885/2000 - Loss: -0.919  noise: 0.010
# Iter 886/2000 - Loss: -0.919  noise: 0.010
# Iter 887/2000 - Loss: -0.919  noise: 0.010
# Iter 888/2000 - Loss: -0.919  noise: 0.010
# Iter 889/2000 - Loss: -0.919  noise: 0.010
# Iter 890/2000 - Loss: -0.920  noise: 0.010
# Iter 891/2000 - Loss: -0.920  noise: 0.010
# Iter 892/2000 - Loss: -0.920  noise: 0.010
# Iter 893/2000 - Loss: -0.920  noise: 0.010
# Iter 894/2000 - Loss: -0.920  noise: 0.010
# Iter 895/2000 - Loss: -0.920  noise: 0.010
# Iter 896/2000 - Loss: -0.921  noise: 0.010
# Iter 897/2000 - Loss: -0.921  noise: 0.010
# Iter 898/2000 - Loss: -0.921  noise: 0.010
# Iter 899/2000 - Loss: -0.921  noise: 0.010
# Iter 900/2000 - Loss: -0.921  noise: 0.010
# Iter 901/2000 - Loss: -0.921  noise: 0.010
# Iter 902/2000 - Loss: -0.922  noise: 0.010
# Iter 903/2000 - Loss: -0.922  noise: 0.010
# Iter 904/2000 - Loss: -0.922  noise: 0.010
# Iter 905/2000 - Loss: -0.922  noise: 0.010
# Iter 906/2000 - Loss: -0.922  noise: 0.010
# Iter 907/2000 - Loss: -0.922  noise: 0.010
# Iter 908/2000 - Loss: -0.923  noise: 0.010
# Iter 909/2000 - Loss: -0.923  noise: 0.010
# Iter 910/2000 - Loss: -0.923  noise: 0.010
# Iter 911/2000 - Loss: -0.923  noise: 0.010
# Iter 912/2000 - Loss: -0.923  noise: 0.010
# Iter 913/2000 - Loss: -0.923  noise: 0.010
# Iter 914/2000 - Loss: -0.924  noise: 0.010
# Iter 915/2000 - Loss: -0.924  noise: 0.010
# Iter 916/2000 - Loss: -0.924  noise: 0.010
# Iter 917/2000 - Loss: -0.924  noise: 0.010
# Iter 918/2000 - Loss: -0.924  noise: 0.010
# Iter 919/2000 - Loss: -0.924  noise: 0.010
# Iter 920/2000 - Loss: -0.925  noise: 0.010
# Iter 921/2000 - Loss: -0.925  noise: 0.010
# Iter 922/2000 - Loss: -0.925  noise: 0.010
# Iter 923/2000 - Loss: -0.925  noise: 0.010
# Iter 924/2000 - Loss: -0.925  noise: 0.010
# Iter 925/2000 - Loss: -0.925  noise: 0.010
# Iter 926/2000 - Loss: -0.925  noise: 0.010
# Iter 927/2000 - Loss: -0.926  noise: 0.010
# Iter 928/2000 - Loss: -0.926  noise: 0.010
# Iter 929/2000 - Loss: -0.926  noise: 0.010
# Iter 930/2000 - Loss: -0.926  noise: 0.010
# Iter 931/2000 - Loss: -0.926  noise: 0.010
# Iter 932/2000 - Loss: -0.926  noise: 0.010
# Iter 933/2000 - Loss: -0.927  noise: 0.010
# Iter 934/2000 - Loss: -0.927  noise: 0.010
# Iter 935/2000 - Loss: -0.927  noise: 0.010
# Iter 936/2000 - Loss: -0.927  noise: 0.010
# Iter 937/2000 - Loss: -0.927  noise: 0.010
# Iter 938/2000 - Loss: -0.927  noise: 0.010
# Iter 939/2000 - Loss: -0.927  noise: 0.010
# Iter 940/2000 - Loss: -0.928  noise: 0.010
# Iter 941/2000 - Loss: -0.928  noise: 0.010
# Iter 942/2000 - Loss: -0.928  noise: 0.010
# Iter 943/2000 - Loss: -0.928  noise: 0.010
# Iter 944/2000 - Loss: -0.928  noise: 0.010
# Iter 945/2000 - Loss: -0.928  noise: 0.010
# Iter 946/2000 - Loss: -0.928  noise: 0.010
# Iter 947/2000 - Loss: -0.929  noise: 0.010
# Iter 948/2000 - Loss: -0.929  noise: 0.010
# Iter 949/2000 - Loss: -0.929  noise: 0.010
# Iter 950/2000 - Loss: -0.929  noise: 0.010
# Iter 951/2000 - Loss: -0.929  noise: 0.010
# Iter 952/2000 - Loss: -0.929  noise: 0.010
# Iter 953/2000 - Loss: -0.929  noise: 0.010
# Iter 954/2000 - Loss: -0.930  noise: 0.010
# Iter 955/2000 - Loss: -0.930  noise: 0.010
# Iter 956/2000 - Loss: -0.930  noise: 0.010
# Iter 957/2000 - Loss: -0.930  noise: 0.010
# Iter 958/2000 - Loss: -0.930  noise: 0.010
# Iter 959/2000 - Loss: -0.930  noise: 0.010
# Iter 960/2000 - Loss: -0.930  noise: 0.010
# Iter 961/2000 - Loss: -0.931  noise: 0.010
# Iter 962/2000 - Loss: -0.931  noise: 0.010
# Iter 963/2000 - Loss: -0.931  noise: 0.010
# Iter 964/2000 - Loss: -0.931  noise: 0.010
# Iter 965/2000 - Loss: -0.931  noise: 0.010
# Iter 966/2000 - Loss: -0.931  noise: 0.010
# Iter 967/2000 - Loss: -0.931  noise: 0.010
# Iter 968/2000 - Loss: -0.931  noise: 0.010
# Iter 969/2000 - Loss: -0.932  noise: 0.010
# Iter 970/2000 - Loss: -0.932  noise: 0.010
# Iter 971/2000 - Loss: -0.932  noise: 0.010
# Iter 972/2000 - Loss: -0.932  noise: 0.010
# Iter 973/2000 - Loss: -0.932  noise: 0.010
# Iter 974/2000 - Loss: -0.932  noise: 0.010
# Iter 975/2000 - Loss: -0.932  noise: 0.010
# Iter 976/2000 - Loss: -0.932  noise: 0.010
# Iter 977/2000 - Loss: -0.933  noise: 0.010
# Iter 978/2000 - Loss: -0.933  noise: 0.010
# Iter 979/2000 - Loss: -0.933  noise: 0.010
# Iter 980/2000 - Loss: -0.933  noise: 0.010
# Iter 981/2000 - Loss: -0.933  noise: 0.010
# Iter 982/2000 - Loss: -0.933  noise: 0.010
# Iter 983/2000 - Loss: -0.933  noise: 0.010
# Iter 984/2000 - Loss: -0.933  noise: 0.010
# Iter 985/2000 - Loss: -0.934  noise: 0.010
# Iter 986/2000 - Loss: -0.934  noise: 0.010
# Iter 987/2000 - Loss: -0.934  noise: 0.010
# Iter 988/2000 - Loss: -0.934  noise: 0.010
# Iter 989/2000 - Loss: -0.934  noise: 0.010
# Iter 990/2000 - Loss: -0.934  noise: 0.010
# Iter 991/2000 - Loss: -0.934  noise: 0.010
# Iter 992/2000 - Loss: -0.934  noise: 0.010
# Iter 993/2000 - Loss: -0.935  noise: 0.010
# Iter 994/2000 - Loss: -0.935  noise: 0.010
# Iter 995/2000 - Loss: -0.935  noise: 0.010
# Iter 996/2000 - Loss: -0.935  noise: 0.010
# Iter 997/2000 - Loss: -0.935  noise: 0.010
# Iter 998/2000 - Loss: -0.935  noise: 0.010
# Iter 999/2000 - Loss: -0.935  noise: 0.010
# Iter 1000/2000 - Loss: -0.935  noise: 0.010
# Iter 1001/2000 - Loss: -0.936  noise: 0.010
# Iter 1002/2000 - Loss: -0.936  noise: 0.010
# Iter 1003/2000 - Loss: -0.936  noise: 0.010
# Iter 1004/2000 - Loss: -0.936  noise: 0.010
# Iter 1005/2000 - Loss: -0.936  noise: 0.010
# Iter 1006/2000 - Loss: -0.936  noise: 0.010
# Iter 1007/2000 - Loss: -0.936  noise: 0.010
# Iter 1008/2000 - Loss: -0.936  noise: 0.010
# Iter 1009/2000 - Loss: -0.936  noise: 0.010
# Iter 1010/2000 - Loss: -0.937  noise: 0.010
# Iter 1011/2000 - Loss: -0.937  noise: 0.010
# Iter 1012/2000 - Loss: -0.937  noise: 0.010
# Iter 1013/2000 - Loss: -0.937  noise: 0.010
# Iter 1014/2000 - Loss: -0.937  noise: 0.010
# Iter 1015/2000 - Loss: -0.937  noise: 0.010
# Iter 1016/2000 - Loss: -0.937  noise: 0.010
# Iter 1017/2000 - Loss: -0.937  noise: 0.010
# Iter 1018/2000 - Loss: -0.937  noise: 0.010
# Iter 1019/2000 - Loss: -0.938  noise: 0.010
# Iter 1020/2000 - Loss: -0.938  noise: 0.010
# Iter 1021/2000 - Loss: -0.938  noise: 0.010
# Iter 1022/2000 - Loss: -0.938  noise: 0.010
# Iter 1023/2000 - Loss: -0.938  noise: 0.010
# Iter 1024/2000 - Loss: -0.938  noise: 0.010
# Iter 1025/2000 - Loss: -0.938  noise: 0.010
# Iter 1026/2000 - Loss: -0.938  noise: 0.010
# Iter 1027/2000 - Loss: -0.938  noise: 0.010
# Iter 1028/2000 - Loss: -0.939  noise: 0.010
# Iter 1029/2000 - Loss: -0.939  noise: 0.010
# Iter 1030/2000 - Loss: -0.939  noise: 0.010
# Iter 1031/2000 - Loss: -0.939  noise: 0.010
# Iter 1032/2000 - Loss: -0.939  noise: 0.010
# Iter 1033/2000 - Loss: -0.939  noise: 0.010
# Iter 1034/2000 - Loss: -0.939  noise: 0.010
# Iter 1035/2000 - Loss: -0.939  noise: 0.010
# Iter 1036/2000 - Loss: -0.939  noise: 0.010
# Iter 1037/2000 - Loss: -0.939  noise: 0.010
# Iter 1038/2000 - Loss: -0.940  noise: 0.010
# Iter 1039/2000 - Loss: -0.940  noise: 0.010
# Iter 1040/2000 - Loss: -0.940  noise: 0.010
# Iter 1041/2000 - Loss: -0.940  noise: 0.010
# Iter 1042/2000 - Loss: -0.940  noise: 0.010
# Iter 1043/2000 - Loss: -0.940  noise: 0.010
# Iter 1044/2000 - Loss: -0.940  noise: 0.010
# Iter 1045/2000 - Loss: -0.940  noise: 0.010
# Iter 1046/2000 - Loss: -0.940  noise: 0.010
# Iter 1047/2000 - Loss: -0.941  noise: 0.010
# Iter 1048/2000 - Loss: -0.941  noise: 0.010
# Iter 1049/2000 - Loss: -0.941  noise: 0.010
# Iter 1050/2000 - Loss: -0.941  noise: 0.010
# Iter 1051/2000 - Loss: -0.941  noise: 0.010
# Iter 1052/2000 - Loss: -0.941  noise: 0.010
# Iter 1053/2000 - Loss: -0.941  noise: 0.010
# Iter 1054/2000 - Loss: -0.941  noise: 0.010
# Iter 1055/2000 - Loss: -0.941  noise: 0.010
# Iter 1056/2000 - Loss: -0.941  noise: 0.010
# Iter 1057/2000 - Loss: -0.942  noise: 0.010
# Iter 1058/2000 - Loss: -0.942  noise: 0.010
# Iter 1059/2000 - Loss: -0.942  noise: 0.010
# Iter 1060/2000 - Loss: -0.942  noise: 0.010
# Iter 1061/2000 - Loss: -0.942  noise: 0.010
# Iter 1062/2000 - Loss: -0.942  noise: 0.010
# Iter 1063/2000 - Loss: -0.942  noise: 0.010
# Iter 1064/2000 - Loss: -0.942  noise: 0.010
# Iter 1065/2000 - Loss: -0.942  noise: 0.010
# Iter 1066/2000 - Loss: -0.942  noise: 0.010
# Iter 1067/2000 - Loss: -0.943  noise: 0.010
# Iter 1068/2000 - Loss: -0.943  noise: 0.010
# Iter 1069/2000 - Loss: -0.943  noise: 0.010
# Iter 1070/2000 - Loss: -0.943  noise: 0.010
# Iter 1071/2000 - Loss: -0.943  noise: 0.010
# Iter 1072/2000 - Loss: -0.943  noise: 0.010
# Iter 1073/2000 - Loss: -0.943  noise: 0.010
# Iter 1074/2000 - Loss: -0.943  noise: 0.010
# Iter 1075/2000 - Loss: -0.943  noise: 0.010
# Iter 1076/2000 - Loss: -0.943  noise: 0.010
# Iter 1077/2000 - Loss: -0.944  noise: 0.010
# Iter 1078/2000 - Loss: -0.944  noise: 0.010
# Iter 1079/2000 - Loss: -0.944  noise: 0.010
# Iter 1080/2000 - Loss: -0.944  noise: 0.010
# Iter 1081/2000 - Loss: -0.944  noise: 0.010
# Iter 1082/2000 - Loss: -0.944  noise: 0.010
# Iter 1083/2000 - Loss: -0.944  noise: 0.010
# Iter 1084/2000 - Loss: -0.944  noise: 0.010
# Iter 1085/2000 - Loss: -0.944  noise: 0.010
# Iter 1086/2000 - Loss: -0.944  noise: 0.010
# Iter 1087/2000 - Loss: -0.944  noise: 0.010
# Iter 1088/2000 - Loss: -0.945  noise: 0.010
# Iter 1089/2000 - Loss: -0.945  noise: 0.010
# Iter 1090/2000 - Loss: -0.945  noise: 0.010
# Iter 1091/2000 - Loss: -0.945  noise: 0.010
# Iter 1092/2000 - Loss: -0.945  noise: 0.010
# Iter 1093/2000 - Loss: -0.945  noise: 0.010
# Iter 1094/2000 - Loss: -0.945  noise: 0.010
# Iter 1095/2000 - Loss: -0.945  noise: 0.010
# Iter 1096/2000 - Loss: -0.945  noise: 0.010
# Iter 1097/2000 - Loss: -0.945  noise: 0.010
# Iter 1098/2000 - Loss: -0.945  noise: 0.010
# Iter 1099/2000 - Loss: -0.946  noise: 0.010
# Iter 1100/2000 - Loss: -0.946  noise: 0.010
# Iter 1101/2000 - Loss: -0.946  noise: 0.010
# Iter 1102/2000 - Loss: -0.946  noise: 0.010
# Iter 1103/2000 - Loss: -0.946  noise: 0.010
# Iter 1104/2000 - Loss: -0.946  noise: 0.010
# Iter 1105/2000 - Loss: -0.946  noise: 0.010
# Iter 1106/2000 - Loss: -0.946  noise: 0.010
# Iter 1107/2000 - Loss: -0.946  noise: 0.010
# Iter 1108/2000 - Loss: -0.946  noise: 0.010
# Iter 1109/2000 - Loss: -0.946  noise: 0.010
# Iter 1110/2000 - Loss: -0.946  noise: 0.010
# Iter 1111/2000 - Loss: -0.947  noise: 0.010
# Iter 1112/2000 - Loss: -0.947  noise: 0.010
# Iter 1113/2000 - Loss: -0.947  noise: 0.010
# Iter 1114/2000 - Loss: -0.947  noise: 0.010
# Iter 1115/2000 - Loss: -0.947  noise: 0.010
# Iter 1116/2000 - Loss: -0.947  noise: 0.010
# Iter 1117/2000 - Loss: -0.947  noise: 0.010
# Iter 1118/2000 - Loss: -0.947  noise: 0.010
# Iter 1119/2000 - Loss: -0.947  noise: 0.010
# Iter 1120/2000 - Loss: -0.947  noise: 0.010
# Iter 1121/2000 - Loss: -0.947  noise: 0.010
# ...
# Iter 1638/2000 - Loss: -0.971  noise: 0.009
# Iter 1639/2000 - Loss: -0.971  noise: 0.009
# Iter 1640/2000 - Loss: -0.971  noise: 0.009
# Iter 1641/2000 - Loss: -0.971  noise: 0.009
# Iter 1642/2000 - Loss: -0.971  noise: 0.009
# Iter 1643/2000 - Loss: -0.971  noise: 0.009
# Iter 1644/2000 - Loss: -0.971  noise: 0.009
# Iter 1645/2000 - Loss: -0.971  noise: 0.009
# Iter 1646/2000 - Loss: -0.971  noise: 0.009
# Iter 1647/2000 - Loss: -0.971  noise: 0.009
# Iter 1648/2000 - Loss: -0.971  noise: 0.009
# Iter 1649/2000 - Loss: -0.971  noise: 0.009
# Iter 1650/2000 - Loss: -0.971  noise: 0.009
# Iter 1651/2000 - Loss: -0.971  noise: 0.009
# Iter 1652/2000 - Loss: -0.971  noise: 0.009
# Iter 1653/2000 - Loss: -0.971  noise: 0.009
# Iter 1654/2000 - Loss: -0.971  noise: 0.009
# Iter 1655/2000 - Loss: -0.971  noise: 0.009
# Iter 1656/2000 - Loss: -0.971  noise: 0.009
# Iter 1657/2000 - Loss: -0.971  noise: 0.009
# Iter 1658/2000 - Loss: -0.971  noise: 0.009
# Iter 1659/2000 - Loss: -0.971  noise: 0.009
# Iter 1660/2000 - Loss: -0.971  noise: 0.009
# Iter 1661/2000 - Loss: -0.972  noise: 0.009
# Iter 1662/2000 - Loss: -0.972  noise: 0.009
# Iter 1663/2000 - Loss: -0.972  noise: 0.009
# Iter 1664/2000 - Loss: -0.972  noise: 0.009
# Iter 1665/2000 - Loss: -0.972  noise: 0.009
# Iter 1666/2000 - Loss: -0.972  noise: 0.009
# Iter 1667/2000 - Loss: -0.972  noise: 0.009
# Iter 1668/2000 - Loss: -0.972  noise: 0.009
# Iter 1669/2000 - Loss: -0.972  noise: 0.009
# Iter 1670/2000 - Loss: -0.972  noise: 0.009
# Iter 1671/2000 - Loss: -0.972  noise: 0.009
# Iter 1672/2000 - Loss: -0.972  noise: 0.009
# Iter 1673/2000 - Loss: -0.972  noise: 0.009
# Iter 1674/2000 - Loss: -0.972  noise: 0.009
# Iter 1675/2000 - Loss: -0.972  noise: 0.009
# Iter 1676/2000 - Loss: -0.972  noise: 0.009
# Iter 1677/2000 - Loss: -0.972  noise: 0.009
# Iter 1678/2000 - Loss: -0.972  noise: 0.009
# Iter 1679/2000 - Loss: -0.972  noise: 0.009
# Iter 1680/2000 - Loss: -0.972  noise: 0.009
# Iter 1681/2000 - Loss: -0.972  noise: 0.009
# Iter 1682/2000 - Loss: -0.972  noise: 0.009
# Iter 1683/2000 - Loss: -0.972  noise: 0.009
# Iter 1684/2000 - Loss: -0.972  noise: 0.009
# Iter 1685/2000 - Loss: -0.972  noise: 0.009
# Iter 1686/2000 - Loss: -0.972  noise: 0.009
# Iter 1687/2000 - Loss: -0.972  noise: 0.009
# Iter 1688/2000 - Loss: -0.972  noise: 0.009
# Iter 1689/2000 - Loss: -0.972  noise: 0.009
# Iter 1690/2000 - Loss: -0.972  noise: 0.009
# Iter 1691/2000 - Loss: -0.972  noise: 0.009
# Iter 1692/2000 - Loss: -0.972  noise: 0.009
# Iter 1693/2000 - Loss: -0.972  noise: 0.009
# Iter 1694/2000 - Loss: -0.972  noise: 0.009
# Iter 1695/2000 - Loss: -0.972  noise: 0.009
# Iter 1696/2000 - Loss: -0.972  noise: 0.009
# Iter 1697/2000 - Loss: -0.972  noise: 0.009
# Iter 1698/2000 - Loss: -0.972  noise: 0.009
# Iter 1699/2000 - Loss: -0.972  noise: 0.009
# Iter 1700/2000 - Loss: -0.972  noise: 0.009
# Iter 1701/2000 - Loss: -0.972  noise: 0.009
# Iter 1702/2000 - Loss: -0.972  noise: 0.009
# Iter 1703/2000 - Loss: -0.972  noise: 0.009
# Iter 1704/2000 - Loss: -0.972  noise: 0.009
# Iter 1705/2000 - Loss: -0.972  noise: 0.009
# Iter 1706/2000 - Loss: -0.972  noise: 0.009
# Iter 1707/2000 - Loss: -0.972  noise: 0.009
# Iter 1708/2000 - Loss: -0.972  noise: 0.009
# Iter 1709/2000 - Loss: -0.972  noise: 0.009
# Iter 1710/2000 - Loss: -0.973  noise: 0.009
# Iter 1711/2000 - Loss: -0.973  noise: 0.009
# Iter 1712/2000 - Loss: -0.973  noise: 0.009
# Iter 1713/2000 - Loss: -0.973  noise: 0.009
# Iter 1714/2000 - Loss: -0.973  noise: 0.009
# Iter 1715/2000 - Loss: -0.973  noise: 0.009
# Iter 1716/2000 - Loss: -0.973  noise: 0.009
# Iter 1717/2000 - Loss: -0.973  noise: 0.009
# Iter 1718/2000 - Loss: -0.973  noise: 0.009
# Iter 1719/2000 - Loss: -0.973  noise: 0.009
# Iter 1720/2000 - Loss: -0.973  noise: 0.009
# Iter 1721/2000 - Loss: -0.973  noise: 0.009
# Iter 1722/2000 - Loss: -0.973  noise: 0.009
# Iter 1723/2000 - Loss: -0.973  noise: 0.009
# Iter 1724/2000 - Loss: -0.973  noise: 0.009
# Iter 1725/2000 - Loss: -0.973  noise: 0.009
# Iter 1726/2000 - Loss: -0.973  noise: 0.009
# Iter 1727/2000 - Loss: -0.973  noise: 0.009
# Iter 1728/2000 - Loss: -0.973  noise: 0.009
# Iter 1729/2000 - Loss: -0.973  noise: 0.009
# Iter 1730/2000 - Loss: -0.973  noise: 0.009
# Iter 1731/2000 - Loss: -0.973  noise: 0.009
# Iter 1732/2000 - Loss: -0.973  noise: 0.009
# Iter 1733/2000 - Loss: -0.973  noise: 0.009
# Iter 1734/2000 - Loss: -0.973  noise: 0.009
# Iter 1735/2000 - Loss: -0.973  noise: 0.009
# Iter 1736/2000 - Loss: -0.973  noise: 0.009
# Iter 1737/2000 - Loss: -0.973  noise: 0.009
# Iter 1738/2000 - Loss: -0.973  noise: 0.009
# Iter 1739/2000 - Loss: -0.973  noise: 0.009
# Iter 1740/2000 - Loss: -0.973  noise: 0.009
# Iter 1741/2000 - Loss: -0.973  noise: 0.009
# Iter 1742/2000 - Loss: -0.973  noise: 0.009
# Iter 1743/2000 - Loss: -0.973  noise: 0.009
# Iter 1744/2000 - Loss: -0.973  noise: 0.009
# Iter 1745/2000 - Loss: -0.973  noise: 0.009
# Iter 1746/2000 - Loss: -0.973  noise: 0.009
# Iter 1747/2000 - Loss: -0.973  noise: 0.009
# Iter 1748/2000 - Loss: -0.973  noise: 0.009
# Iter 1749/2000 - Loss: -0.973  noise: 0.009
# Iter 1750/2000 - Loss: -0.973  noise: 0.009
# Iter 1751/2000 - Loss: -0.973  noise: 0.009
# Iter 1752/2000 - Loss: -0.973  noise: 0.009
# Iter 1753/2000 - Loss: -0.973  noise: 0.009
# Iter 1754/2000 - Loss: -0.974  noise: 0.009
# Iter 1755/2000 - Loss: -0.974  noise: 0.009
# Iter 1756/2000 - Loss: -0.974  noise: 0.009
# Iter 1757/2000 - Loss: -0.974  noise: 0.009
# Iter 1758/2000 - Loss: -0.974  noise: 0.009
# Iter 1759/2000 - Loss: -0.974  noise: 0.009
# Iter 1760/2000 - Loss: -0.974  noise: 0.009
# Iter 1761/2000 - Loss: -0.974  noise: 0.009
# Iter 1762/2000 - Loss: -0.974  noise: 0.009
# Iter 1763/2000 - Loss: -0.974  noise: 0.009
# Iter 1764/2000 - Loss: -0.974  noise: 0.009
# Iter 1765/2000 - Loss: -0.974  noise: 0.009
# Iter 1766/2000 - Loss: -0.974  noise: 0.009
# Iter 1767/2000 - Loss: -0.974  noise: 0.009
# Iter 1768/2000 - Loss: -0.974  noise: 0.009
# Iter 1769/2000 - Loss: -0.974  noise: 0.009
# Iter 1770/2000 - Loss: -0.974  noise: 0.009
# Iter 1771/2000 - Loss: -0.974  noise: 0.009
# Iter 1772/2000 - Loss: -0.974  noise: 0.009
# Iter 1773/2000 - Loss: -0.974  noise: 0.009
# Iter 1774/2000 - Loss: -0.974  noise: 0.009
# Iter 1775/2000 - Loss: -0.974  noise: 0.009
# Iter 1776/2000 - Loss: -0.974  noise: 0.009
# Iter 1777/2000 - Loss: -0.974  noise: 0.009
# Iter 1778/2000 - Loss: -0.974  noise: 0.009
# Iter 1779/2000 - Loss: -0.974  noise: 0.009
# Iter 1780/2000 - Loss: -0.974  noise: 0.009
# Iter 1781/2000 - Loss: -0.974  noise: 0.009
# Iter 1782/2000 - Loss: -0.974  noise: 0.009
# Iter 1783/2000 - Loss: -0.974  noise: 0.009
# Iter 1784/2000 - Loss: -0.974  noise: 0.009
# Iter 1785/2000 - Loss: -0.974  noise: 0.009
# Iter 1786/2000 - Loss: -0.974  noise: 0.009
# Iter 1787/2000 - Loss: -0.974  noise: 0.009
# Iter 1788/2000 - Loss: -0.974  noise: 0.009
# Iter 1789/2000 - Loss: -0.974  noise: 0.009
# Iter 1790/2000 - Loss: -0.974  noise: 0.009
# Iter 1791/2000 - Loss: -0.974  noise: 0.009
# Iter 1792/2000 - Loss: -0.974  noise: 0.009
# Iter 1793/2000 - Loss: -0.974  noise: 0.009
# Iter 1794/2000 - Loss: -0.974  noise: 0.009
# Iter 1795/2000 - Loss: -0.974  noise: 0.009
# Iter 1796/2000 - Loss: -0.974  noise: 0.009
# Iter 1797/2000 - Loss: -0.974  noise: 0.009
# Iter 1798/2000 - Loss: -0.974  noise: 0.009
# Iter 1799/2000 - Loss: -0.974  noise: 0.009
# Iter 1800/2000 - Loss: -0.974  noise: 0.009
# Iter 1801/2000 - Loss: -0.974  noise: 0.009
# Iter 1802/2000 - Loss: -0.974  noise: 0.009
# Iter 1803/2000 - Loss: -0.974  noise: 0.009
# Iter 1804/2000 - Loss: -0.974  noise: 0.009
# Iter 1805/2000 - Loss: -0.975  noise: 0.009
# Iter 1806/2000 - Loss: -0.975  noise: 0.009
# Iter 1807/2000 - Loss: -0.975  noise: 0.009
# Iter 1808/2000 - Loss: -0.975  noise: 0.009
# Iter 1809/2000 - Loss: -0.975  noise: 0.009
# Iter 1810/2000 - Loss: -0.975  noise: 0.009
# Iter 1811/2000 - Loss: -0.975  noise: 0.009
# Iter 1812/2000 - Loss: -0.975  noise: 0.009
# Iter 1813/2000 - Loss: -0.975  noise: 0.009
# Iter 1814/2000 - Loss: -0.975  noise: 0.009
# Iter 1815/2000 - Loss: -0.975  noise: 0.009
# Iter 1816/2000 - Loss: -0.975  noise: 0.009
# Iter 1817/2000 - Loss: -0.975  noise: 0.009
# Iter 1818/2000 - Loss: -0.975  noise: 0.009
# Iter 1819/2000 - Loss: -0.975  noise: 0.009
# Iter 1820/2000 - Loss: -0.975  noise: 0.009
# Iter 1821/2000 - Loss: -0.975  noise: 0.009
# Iter 1822/2000 - Loss: -0.975  noise: 0.009
# Iter 1823/2000 - Loss: -0.975  noise: 0.009
# Iter 1824/2000 - Loss: -0.975  noise: 0.009
# Iter 1825/2000 - Loss: -0.975  noise: 0.009
# Iter 1826/2000 - Loss: -0.975  noise: 0.009
# Iter 1827/2000 - Loss: -0.975  noise: 0.009
# Iter 1828/2000 - Loss: -0.975  noise: 0.009
# Iter 1829/2000 - Loss: -0.975  noise: 0.009
# Iter 1830/2000 - Loss: -0.975  noise: 0.009
# Iter 1831/2000 - Loss: -0.975  noise: 0.009
# Iter 1832/2000 - Loss: -0.975  noise: 0.009
# Iter 1833/2000 - Loss: -0.975  noise: 0.009
# Iter 1834/2000 - Loss: -0.975  noise: 0.009
# Iter 1835/2000 - Loss: -0.975  noise: 0.009
# Iter 1836/2000 - Loss: -0.975  noise: 0.009
# Iter 1837/2000 - Loss: -0.975  noise: 0.009
# Iter 1838/2000 - Loss: -0.975  noise: 0.009
# Iter 1839/2000 - Loss: -0.975  noise: 0.009
# Iter 1840/2000 - Loss: -0.975  noise: 0.009
# Iter 1841/2000 - Loss: -0.975  noise: 0.009
# Iter 1842/2000 - Loss: -0.975  noise: 0.009
# Iter 1843/2000 - Loss: -0.975  noise: 0.009
# Iter 1844/2000 - Loss: -0.975  noise: 0.009
# Iter 1845/2000 - Loss: -0.975  noise: 0.009
# Iter 1846/2000 - Loss: -0.975  noise: 0.009
# Iter 1847/2000 - Loss: -0.975  noise: 0.009
# Iter 1848/2000 - Loss: -0.975  noise: 0.009
# Iter 1849/2000 - Loss: -0.975  noise: 0.009
# Iter 1850/2000 - Loss: -0.975  noise: 0.009
# Iter 1851/2000 - Loss: -0.975  noise: 0.009
# Iter 1852/2000 - Loss: -0.975  noise: 0.009
# Iter 1853/2000 - Loss: -0.975  noise: 0.009
# Iter 1854/2000 - Loss: -0.975  noise: 0.009
# Iter 1855/2000 - Loss: -0.975  noise: 0.009
# Iter 1856/2000 - Loss: -0.975  noise: 0.009
# Iter 1857/2000 - Loss: -0.976  noise: 0.009
# Iter 1858/2000 - Loss: -0.976  noise: 0.009
# Iter 1859/2000 - Loss: -0.976  noise: 0.009
# Iter 1860/2000 - Loss: -0.976  noise: 0.009
# Iter 1861/2000 - Loss: -0.976  noise: 0.009
# Iter 1862/2000 - Loss: -0.976  noise: 0.009
# Iter 1863/2000 - Loss: -0.976  noise: 0.009
# Iter 1864/2000 - Loss: -0.976  noise: 0.009
# Iter 1865/2000 - Loss: -0.976  noise: 0.009
# Iter 1866/2000 - Loss: -0.976  noise: 0.009
# Iter 1867/2000 - Loss: -0.976  noise: 0.009
# Iter 1868/2000 - Loss: -0.976  noise: 0.009
# Iter 1869/2000 - Loss: -0.976  noise: 0.009
# Iter 1870/2000 - Loss: -0.976  noise: 0.009
# Iter 1871/2000 - Loss: -0.976  noise: 0.009
# Iter 1872/2000 - Loss: -0.976  noise: 0.009
# Iter 1873/2000 - Loss: -0.976  noise: 0.009
# Iter 1874/2000 - Loss: -0.976  noise: 0.009
# Iter 1875/2000 - Loss: -0.976  noise: 0.009
# Iter 1876/2000 - Loss: -0.976  noise: 0.009
# Iter 1877/2000 - Loss: -0.976  noise: 0.009
# Iter 1878/2000 - Loss: -0.976  noise: 0.009
# Iter 1879/2000 - Loss: -0.976  noise: 0.009
# Iter 1880/2000 - Loss: -0.976  noise: 0.009
# Iter 1881/2000 - Loss: -0.976  noise: 0.009
# Iter 1882/2000 - Loss: -0.976  noise: 0.009
# Iter 1883/2000 - Loss: -0.976  noise: 0.009
# Iter 1884/2000 - Loss: -0.976  noise: 0.009
# Iter 1885/2000 - Loss: -0.976  noise: 0.009
# Iter 1886/2000 - Loss: -0.976  noise: 0.009
# Iter 1887/2000 - Loss: -0.976  noise: 0.009
# Iter 1888/2000 - Loss: -0.976  noise: 0.009
# Iter 1889/2000 - Loss: -0.976  noise: 0.009
# Iter 1890/2000 - Loss: -0.976  noise: 0.009
# Iter 1891/2000 - Loss: -0.976  noise: 0.009
# Iter 1892/2000 - Loss: -0.976  noise: 0.009
# Iter 1893/2000 - Loss: -0.976  noise: 0.009
# Iter 1894/2000 - Loss: -0.976  noise: 0.009
# Iter 1895/2000 - Loss: -0.976  noise: 0.009
# Iter 1896/2000 - Loss: -0.976  noise: 0.009
# Iter 1897/2000 - Loss: -0.976  noise: 0.009
# Iter 1898/2000 - Loss: -0.976  noise: 0.009
# Iter 1899/2000 - Loss: -0.976  noise: 0.009
# Iter 1900/2000 - Loss: -0.976  noise: 0.009
# Iter 1901/2000 - Loss: -0.976  noise: 0.009
# Iter 1902/2000 - Loss: -0.976  noise: 0.009
# Iter 1903/2000 - Loss: -0.976  noise: 0.009
# Iter 1904/2000 - Loss: -0.976  noise: 0.009
# Iter 1905/2000 - Loss: -0.976  noise: 0.009
# Iter 1906/2000 - Loss: -0.976  noise: 0.009
# Iter 1907/2000 - Loss: -0.976  noise: 0.009
# Iter 1908/2000 - Loss: -0.976  noise: 0.009
# Iter 1909/2000 - Loss: -0.976  noise: 0.009
# Iter 1910/2000 - Loss: -0.976  noise: 0.009
# Iter 1911/2000 - Loss: -0.976  noise: 0.009
# Iter 1912/2000 - Loss: -0.976  noise: 0.009
# Iter 1913/2000 - Loss: -0.976  noise: 0.009
# Iter 1914/2000 - Loss: -0.976  noise: 0.009
# Iter 1915/2000 - Loss: -0.976  noise: 0.009
# Iter 1916/2000 - Loss: -0.976  noise: 0.009
# Iter 1917/2000 - Loss: -0.976  noise: 0.009
# Iter 1918/2000 - Loss: -0.976  noise: 0.009
# Iter 1919/2000 - Loss: -0.976  noise: 0.009
# Iter 1920/2000 - Loss: -0.976  noise: 0.009
# Iter 1921/2000 - Loss: -0.976  noise: 0.009
# Iter 1922/2000 - Loss: -0.977  noise: 0.009
# Iter 1923/2000 - Loss: -0.977  noise: 0.009
# Iter 1924/2000 - Loss: -0.977  noise: 0.009
# Iter 1925/2000 - Loss: -0.977  noise: 0.009
# Iter 1926/2000 - Loss: -0.977  noise: 0.009
# Iter 1927/2000 - Loss: -0.977  noise: 0.009
# Iter 1928/2000 - Loss: -0.977  noise: 0.009
# Iter 1929/2000 - Loss: -0.977  noise: 0.009
# Iter 1930/2000 - Loss: -0.977  noise: 0.009
# Iter 1931/2000 - Loss: -0.977  noise: 0.009
# Iter 1932/2000 - Loss: -0.977  noise: 0.009
# Iter 1933/2000 - Loss: -0.977  noise: 0.009
# Iter 1934/2000 - Loss: -0.977  noise: 0.009
# Iter 1935/2000 - Loss: -0.977  noise: 0.009
# Iter 1936/2000 - Loss: -0.977  noise: 0.009
# Iter 1937/2000 - Loss: -0.977  noise: 0.009
# Iter 1938/2000 - Loss: -0.977  noise: 0.009
# Iter 1939/2000 - Loss: -0.977  noise: 0.009
# Iter 1940/2000 - Loss: -0.977  noise: 0.009
# Iter 1941/2000 - Loss: -0.977  noise: 0.009
# Iter 1942/2000 - Loss: -0.977  noise: 0.009
# Iter 1943/2000 - Loss: -0.977  noise: 0.009
# Iter 1944/2000 - Loss: -0.977  noise: 0.009
# Iter 1945/2000 - Loss: -0.977  noise: 0.009
# Iter 1946/2000 - Loss: -0.977  noise: 0.009
# Iter 1947/2000 - Loss: -0.977  noise: 0.009
# Iter 1948/2000 - Loss: -0.977  noise: 0.009
# Iter 1949/2000 - Loss: -0.977  noise: 0.009
# Iter 1950/2000 - Loss: -0.977  noise: 0.009
# Iter 1951/2000 - Loss: -0.977  noise: 0.009
# Iter 1952/2000 - Loss: -0.977  noise: 0.009
# Iter 1953/2000 - Loss: -0.977  noise: 0.009
# Iter 1954/2000 - Loss: -0.977  noise: 0.009
# Iter 1955/2000 - Loss: -0.977  noise: 0.009
# Iter 1956/2000 - Loss: -0.977  noise: 0.009
# Iter 1957/2000 - Loss: -0.977  noise: 0.009
# Iter 1958/2000 - Loss: -0.977  noise: 0.009
# Iter 1959/2000 - Loss: -0.977  noise: 0.009
# Iter 1960/2000 - Loss: -0.977  noise: 0.009
# Iter 1961/2000 - Loss: -0.977  noise: 0.009
# Iter 1962/2000 - Loss: -0.977  noise: 0.009
# Iter 1963/2000 - Loss: -0.977  noise: 0.009
# Iter 1964/2000 - Loss: -0.977  noise: 0.009
# Iter 1965/2000 - Loss: -0.977  noise: 0.009
# Iter 1966/2000 - Loss: -0.977  noise: 0.009
# Iter 1967/2000 - Loss: -0.977  noise: 0.009
# Iter 1968/2000 - Loss: -0.977  noise: 0.009
# Iter 1969/2000 - Loss: -0.977  noise: 0.009
# Iter 1970/2000 - Loss: -0.977  noise: 0.009
# Iter 1971/2000 - Loss: -0.977  noise: 0.009
# Iter 1972/2000 - Loss: -0.977  noise: 0.009
# Iter 1973/2000 - Loss: -0.977  noise: 0.009
# Iter 1974/2000 - Loss: -0.977  noise: 0.009
# Iter 1975/2000 - Loss: -0.977  noise: 0.009
# Iter 1976/2000 - Loss: -0.977  noise: 0.009
# Iter 1977/2000 - Loss: -0.977  noise: 0.009
# Iter 1978/2000 - Loss: -0.977  noise: 0.009
# Iter 1979/2000 - Loss: -0.977  noise: 0.009
# Iter 1980/2000 - Loss: -0.977  noise: 0.009
# Iter 1981/2000 - Loss: -0.977  noise: 0.009
# Iter 1982/2000 - Loss: -0.977  noise: 0.009
# Iter 1983/2000 - Loss: -0.977  noise: 0.009
# Iter 1984/2000 - Loss: -0.977  noise: 0.009
# Iter 1985/2000 - Loss: -0.978  noise: 0.009
# Iter 1986/2000 - Loss: -0.978  noise: 0.009
# Iter 1987/2000 - Loss: -0.978  noise: 0.009
# Iter 1988/2000 - Loss: -0.978  noise: 0.009
# Iter 1989/2000 - Loss: -0.978  noise: 0.009
# Iter 1990/2000 - Loss: -0.978  noise: 0.009
# Iter 1991/2000 - Loss: -0.978  noise: 0.009
# Iter 1992/2000 - Loss: -0.978  noise: 0.009
# Iter 1993/2000 - Loss: -0.978  noise: 0.009
# Iter 1994/2000 - Loss: -0.978  noise: 0.009
# Iter 1995/2000 - Loss: -0.978  noise: 0.009
# Iter 1996/2000 - Loss: -0.978  noise: 0.009
# Iter 1997/2000 - Loss: -0.978  noise: 0.009
# Iter 1998/2000 - Loss: -0.978  noise: 0.009
# Iter 1999/2000 - Loss: -0.978  noise: 0.009
# Iter 2000/2000 - Loss: -0.978  noise: 0.009

# %%
# save models 
#torch.save(model.state_dict(), '../../learnedModels/deterministicCase/GPwithGPyTorch/multi_RatQuad_gpytorch0.009Rank(1)2kTrain(8k)')

# %%
# Get into evaluation (predictive posterior) mode

model.load_state_dict(torch.load('../../learnedModels/deterministicCase/GPwithGPyTorch/multi_RatQuad_gpytorch0.009Rank(1)2kTrain(8k)'))

model.eval()
likelihood.eval()

mean = np.zeros((X_prior.shape[0],2))
lower = np.zeros((X_prior.shape[0],2))
upper = np.zeros((X_prior.shape[0],2))

# , gpytorch.settings.fast_pred_var()
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    for i in range(X_prior.shape[0]):
        observed_pred = likelihood(model(X_prior[i,:].reshape(1,-1)))
        if i%50==0:
            print(i)
        interMean = observed_pred.mean
        mean[i,:] = interMean.cpu().numpy()
        interLow, interUp = observed_pred.confidence_region()
        lower[i,:], upper[i,:] = interLow.cpu().numpy(), interUp.cpu().numpy()
        #torch.cuda.empty_cache()
# Out:
# /work/flemingc/belal/anaconda3/envs/pytorch/lib/python3.10/site-packages/gpytorch/means/constant_mean.py:20: OldVersionWarning: You have loaded a GP model with a ConstantMean  from a previous version of GPyTorch. The mean module parameter `constant` has been renamed to `raw_constant`. Additionally, the shape of `raw_constant` is now *batch_shape, whereas the shape of `constant` was *batch_shape x 1. We have updated the name/shape of the parameter in your state dict, but we recommend that you re-save your model.
#   warnings.warn(
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 10050
# 10100
# 10150
# 10200
# 10250
# 10300
# 10350
# 10400
# 10450
# 10500
# 10550
# 10600
# 10650
# 10700
# 10750
# 10800
# 10850
# 10900
# 10950
# 11000
# 11050
# 11100
# 11150
# 11200
# 11250
# 11300
# 11350
# 11400
# 11450
# 11500
# 11550
# 11600
# 11650
# 11700
# 11750
# 11800
# 11850
# 11900
# 11950

# %%
# Putting back on CPU
X_train = X_train.cpu()
Y_train = Y_train.cpu()
X_prior = X_prior.cpu()

# %%
star_Traj = 4000
mids_Traj = 8000
ends_Traj = 11000

# Initialize plot
fig, ax = plt.subplots(2)

fig.set_figheight(12)
fig.set_figwidth(16)

# Get upper and lower confidence bounds
ax[0].plot(timeSteps[star_Traj:mids_Traj], Y_train_theta[star_Traj:], 'k*')
ax[0].plot(timeSteps[mids_Traj:ends_Traj], Y_test_theta[:ends_Traj-mids_Traj], 'g*')
ax[0].plot(timeSteps[star_Traj:ends_Traj], mean[:,0][star_Traj:ends_Traj], 'b')
# Shade between the lower and upper confidence bounds
ax[0].fill_between(timeSteps[star_Traj:ends_Traj], lower[:,0][star_Traj:ends_Traj], upper[:,0][star_Traj:ends_Traj], alpha=0.3)
#ax.set_ylim([-3, 3])
ax[0].legend(['Observed Data', 'Mean', 'Confidence'])

# Get upper and lower confidence bounds
ax[1].plot(timeSteps[star_Traj:mids_Traj], Y_train_x[star_Traj:], 'k*')
ax[1].plot(timeSteps[mids_Traj:ends_Traj], Y_test_x[:ends_Traj-mids_Traj], 'g*')
ax[1].plot(timeSteps[star_Traj:ends_Traj], mean[:,1][star_Traj:ends_Traj], 'b')
# Shade between the lower and upper confidence bounds
ax[1].fill_between(timeSteps[star_Traj:ends_Traj], lower[:,1][star_Traj:ends_Traj], upper[:,1][star_Traj:ends_Traj], alpha=0.3)
#ax.set_ylim([-3, 3])
ax[1].legend(['Observed Data', 'Mean', 'Confidence'])
#plt.savefig('MultiTaskRank(1)(009)Pred2kTrain(8k)')

# %% [markdown]
# # Loss Plot

# %%
style.use('seaborn-white')

star_Traj = 0
mids_Traj = 4000
ends_Traj = 4300

# Initialize plot
fig, ax = plt.subplots(2)

fig.set_figheight(12)
fig.set_figwidth(16)

ax[0].plot(timeSteps[:training_iter], lossTrain, 'k*')
ax[1].plot(timeSteps[:training_iter], noiseTrain, 'k*')
plt.savefig('MultiTaskRank(2)(009)LN2kTrain(8k)')
# Out:
# /mnt/bgfs/belal/4199077/ipykernel_102490/1934982646.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn-white')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 13>()
#      10 fig.set_figheight(12)
#      11 fig.set_figwidth(16)
# ---> 13 ax[0].plot(timeSteps[:training_iter], lossTrain, 'k*')
#      14 ax[1].plot(timeSteps[:training_iter], noiseTrain, 'k*')
#      15 plt.savefig('MultiTaskRank(2)(009)LN2kTrain(8k)')
#
# NameError: name 'training_iter' is not defined
